# %% [markdown]
# # Postgres in Python - SQLAlchemy
# - In this lesson, we will use the library **SQLAlchemy** to talk to a database from Python.
#
# https://www.sqlalchemy.org/
#
# SQL Alchemy allows us to access SQL via the Python shell/notebook!
#
# Flask is a framework that wraps both the front-end and the back-end and allows us to work between the two!
#
# In the front end we have our HTML, CSS, and JavaScript which interfaces with Python which in turn interacts with our back-end SQL!
#
# ### It's an Object Relational Mapper
# * Map objects to relations
#
# We're going to be mapping - creating a link - between the tables in SQL to the objects in Python
#
# ### So why do we need this?
# - A layer of abstraction, to be db agnostic (T-SQL, P-SQL etc)
# - Remove the need for writing SQL syntax (everyone breathes a sigh of relief!)
# - Enables us to interface with other code, e.g front-end code or other Python stuff
#
# ##### *(pip install sqlalchemy)*

# %% [markdown]
# **Structures to understand:**
#
# * A **Table** that represents a table in a database.
# * A **class object** that represents a Table in Python.
# * How **SQL Alchemy** fits into the larger picture of back and front end
# * The **CRUD** statements, and their equivalent in SQL Alchemy
#     * We'll learn about SQL Alchemy by doing some CRUD

# %% [markdown]
# ### Create - a database connection
# * 1: we create the necessary SQL Alchemy logistics
# * 2: We create our table structures

# %% [markdown]
# - Setup our imports

# %%
from sqlalchemy import*
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy import Integer, String

# %% [markdown]
# #### Have a look at the data structure we are going to access

# %%
import pandas as pd
df = pd.read_csv('ml-latest-small/movies.csv')
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ### Start to create our ORM structures
# - Create a database connection

# %%
HOST = 'localhost'
DATABASE = 'movies'

mac_db_string = f'postgres://{HOST}/{DATABASE}'

# %% [markdown]
# ### echo will print out all the SQL commands we are generating - it prints the downloading script and the SQL as well!

# %%
db = create_engine(mac_db_string, echo=True)

# %% [markdown]
# - So far, we've created a connection between Python and SQL!

# %% [markdown]
# ### Now we can do the simplest form of SQL Alchemy interaction:
# * db.execute( )
# * just put SQL syntax directly into the parantheses

# %%
db.execute('''INSERT INTO movies VALUES(10003, 'Star Wars II', 'Action')''')
# Out:
# 2019-10-02 11:36:34,347 INFO sqlalchemy.engine.base.Engine select version()
# 2019-10-02 11:36:34,361 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-02 11:36:34,367 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-10-02 11:36:34,367 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-02 11:36:34,377 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-10-02 11:36:34,378 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-02 11:36:34,396 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-10-02 11:36:34,396 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-02 11:36:34,398 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-10-02 11:36:34,400 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-02 11:36:34,403 INFO sqlalchemy.engine.base.Engine INSERT INTO movies VALUES(10003, 'Star Wars II', 'Action')
# 2019-10-02 11:36:34,404 INFO sqlalchemy.engine.base.Engine {}
# 2019-10-02 11:36:34,428 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# UniqueViolation: duplicate key value violates unique constraint "movies_pkey"
# DETAIL:  Key (movieid)=(10003) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-5-2d7430838fed> in <module>
# ----> 1 db.execute('''INSERT INTO movies VALUES(10003, 'Star Wars II', 'Action')''')
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2073
#    2074         connection = self.contextual_connect(close_with_result=True)
# -> 2075         return connection.execute(statement, *multiparams, **params)
#    2076
#    2077     def scalar(self, statement, *multiparams, **params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     507
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#     511     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "movies_pkey"
# DETAIL:  Key (movieid)=(10003) already exists.
#  [SQL: "INSERT INTO movies VALUES(10003, 'Star Wars II', 'Action')"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %% [markdown]
# **But this is clunky! We can do better, using SQL Alchemy (Python) code**

# %% [markdown]
# ---

# %% [markdown]
# ### Now we're going to recreate CRUD statements using Python code

# %% [markdown]
# **Create tables**
#
# 1: Setup a declarative base allows to access all aspects of the ORM (imported this at the top)

# %%
base = declarative_base()

# %% [markdown]
# ---

# %% [markdown]
# 2: Now we create our tables:
#
# *We use classes which is a python structure we'll cover soon*

# %% [markdown]
# **A CLASS IS LIKE A FUNCTION - BUT IT ALSO STORES DATA/ATTRIBUTES AS WELL AS BEHAVIOUR!**

# %%
class Test_Movies(base):
    
    __tablename__ = 'test_movies'
    movieId = Column(Integer, primary_key=True)
    title = Column(String)
    genres = Column(String) # Capitals because they are objects from SQL Alchemy
    
    def __repr__(self): # self tells the class it is talking to itself!
        return f'movieId = {self.movieId}, title = {self.title}'

# %% [markdown]
# ---

# %% [markdown]
# 3: Create all tables in the Base
#
# This examines what we've created, and sends appropriate data to the db

# %%
base.metadata.create_all(db)
# Out:
# 2019-10-02 11:37:15,647 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-10-02 11:37:15,648 INFO sqlalchemy.engine.base.Engine {'name': 'test_movies'}

# %% [markdown]
# ---

# %% [markdown]
# #### Update - we update our tables with row information

# %% [markdown]
# Create a session to add items to the tables
#
# Sessions are complicated to explain, they behave like a buffer, which remembers what we're doing in our Python code and updates the database with that information when we tell it to.

# %%
Session = sessionmaker(db)
session = Session()

# %% [markdown]
# Now add items to the tables, the workflow is:
# * Create the stuff you want to add
# * Add the stuff to the session - data is not in the db (its in a buffered state), wipe the ram, wipe what you've done
# * Commit the stuff to the session - data is in the db, the ram is cleared

# %% [markdown]
# **Lets add items one by one using add()**

# %%
# row1 = Test_Movies(movieid=999, title='Mission Impossible', genres='Action')
# session.add(row1)
# session.commit()

# %% [markdown]
# **Lets add items all together in a for loop using add_all()**

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
table_items= []

for i, row in df.iterrows():
    #if not session.query(Test_Movies).filter_by()
    table_items.append(Test_Movies(movieId= row[0], title=row[1], 
                                    genres=row[2]))
session.add_all(table_items)
session.commit()
# Out:
# 2019-10-02 11:38:54,421 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-10-02 11:38:54,597 INFO sqlalchemy.engine.base.Engine INSERT INTO test_movies ("movieId", title, genres) VALUES (%(movieId)s, %(title)s, %(genres)s)
# 2019-10-02 11:38:54,598 INFO sqlalchemy.engine.base.Engine ({'movieId': 1, 'title': 'Toy Story (1995)', 'genres': 'Adventure|Animation|Children|Comedy|Fantasy'}, {'movieId': 2, 'title': 'Jumanji (1995)', 'genres': 'Adventure|Children|Fantasy'}, {'movieId': 3, 'title': 'Grumpier Old Men (1995)', 'genres': 'Comedy|Romance'}, {'movieId': 4, 'title': 'Waiting to Exhale (1995)', 'genres': 'Comedy|Drama|Romance'}, {'movieId': 5, 'title': 'Father of the Bride Part II (1995)', 'genres': 'Comedy'}, {'movieId': 6, 'title': 'Heat (1995)', 'genres': 'Action|Crime|Thriller'}, {'movieId': 7, 'title': 'Sabrina (1995)', 'genres': 'Comedy|Romance'}, {'movieId': 8, 'title': 'Tom and Huck (1995)', 'genres': 'Adventure|Children'}  ... displaying 10 of 9742 total bound parameter sets ...  {'movieId': 193587, 'title': 'Bungo Stray Dogs: Dead Apple (2018)', 'genres': 'Action|Animation'}, {'movieId': 193609, 'title': 'Andrew Dice Clay: Dice Rules (1991)', 'genres': 'Comedy'})
# 2019-10-02 11:38:55,810 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# #### Read - lets do select statements in SQL Alchemy

# %% [markdown]
# Return everything from a table using all()

# %%
# This is the same as doing SELECT * FROM test_movies;
session.query(Test_Movies).all()
# Out:
# 2019-10-02 11:39:06,878 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-10-02 11:39:06,881 INFO sqlalchemy.engine.base.Engine SELECT test_movies."movieId" AS "test_movies_movieId", test_movies.title AS test_movies_title, test_movies.genres AS test_movies_genres
# FROM test_movies
# 2019-10-02 11:39:06,882 INFO sqlalchemy.engine.base.Engine {}
# [movieId = 1, title = Toy Story (1995),
#  movieId = 2, title = Jumanji (1995),
#  movieId = 3, title = Grumpier Old Men (1995),
#  movieId = 4, title = Waiting to Exhale (1995),
#  movieId = 5, title = Father of the Bride Part II (1995),
#  movieId = 6, title = Heat (1995),
#  movieId = 7, title = Sabrina (1995),
#  movieId = 8, title = Tom and Huck (1995),
#  movieId = 9, title = Sudden Death (1995),
#  movieId = 10, title = GoldenEye (1995),
#  movieId = 11, title = American President, The (1995),
#  movieId = 12, title = Dracula: Dead and Loving It (1995),
#  movieId = 13, title = Balto (1995),
#  movieId = 14, title = Nixon (1995),
#  movieId = 15, title = Cutthroat Island (1995),
#  movieId = 16, title = Casino (1995),
#  movieId = 17, title = Sense and Sensibility (1995),
#  movieId = 18, title = Four Rooms (1995),
#  movieId = 19, title = Ace Ventura: When Nature Calls (1995),
#  movieId = 20, title = Money Train (1995),
#  movieId = 21, title = Get Shorty (1995),
#  movieId = 22, title = Copycat (1995),
#  movieId = 23, title = Assassins (1995),
#  movieId = 24, title = Powder (1995),
#  movieId = 25, title = Leaving Las Vegas (1995),
#  movieId = 26, title = Othello (1995),
#  movieId = 27, title = Now and Then (1995),
#  movieId = 28, title = Persuasion (1995),
#  movieId = 29, title = City of Lost Children, The (Cité des enfants perdus, La) (1995),
#  movieId = 30, title = Shanghai Triad (Yao a yao yao dao waipo qiao) (1995),
#  movieId = 31, title = Dangerous Minds (1995),
#  movieId = 32, title = Twelve Monkeys (a.k.a. 12 Monkeys) (1995),
#  movieId = 34, title = Babe (1995),
#  movieId = 36, title = Dead Man Walking (1995),
#  movieId = 38, title = It Takes Two (1995),
#  movieId = 39, title = Clueless (1995),
#  movieId = 40, title = Cry, the Beloved Country (1995),
#  movieId = 41, title = Richard III (1995),
#  movieId = 42, title = Dead Presidents (1995),
#  movieId = 43, title = Restoration (1995),
#  movieId = 44, title = Mortal Kombat (1995),
#  movieId = 45, title = To Die For (1995),
#  movieId = 46, title = How to Make an American Quilt (1995),
#  movieId = 47, title = Seven (a.k.a. Se7en) (1995),
#  movieId = 48, title = Pocahontas (1995),
#  movieId = 49, title = When Night Is Falling (1995),
#  movieId = 50, title = Usual Suspects, The (1995),
#  movieId = 52, title = Mighty Aphrodite (1995),
#  movieId = 53, title = Lamerica (1994),
#  movieId = 54, title = Big Green, The (1995),
#  movieId = 55, title = Georgia (1995),
#  movieId = 57, title = Home for the Holidays (1995),
#  movieId = 58, title = Postman, The (Postino, Il) (1994),
#  movieId = 60, title = Indian in the Cupboard, The (1995),
#  movieId = 61, title = Eye for an Eye (1996),
#  movieId = 62, title = Mr. Holland's Opus (1995),
#  movieId = 63, title = Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996),
#  movieId = 64, title = Two if by Sea (1996),
#  movieId = 65, title = Bio-Dome (1996),
#  movieId = 66, title = Lawnmower Man 2: Beyond Cyberspace (1996),
#  movieId = 68, title = French Twist (Gazon maudit) (1995),
#  movieId = 69, title = Friday (1995),
#  movieId = 70, title = From Dusk Till Dawn (1996),
#  movieId = 71, title = Fair Game (1995),
#  movieId = 72, title = Kicking and Screaming (1995),
#  movieId = 73, title = Misérables, Les (1995),
#  movieId = 74, title = Bed of Roses (1996),
#  movieId = 75, title = Big Bully (1996),
#  movieId = 76, title = Screamers (1995),
#  movieId = 77, title = Nico Icon (1995),
#  movieId = 78, title = Crossing Guard, The (1995),
#  movieId = 79, title = Juror, The (1996),
#  movieId = 80, title = White Balloon, The (Badkonake sefid) (1995),
#  movieId = 81, title = Things to Do in Denver When You're Dead (1995),
#  movieId = 82, title = Antonia's Line (Antonia) (1995),
#  movieId = 83, title = Once Upon a Time... When We Were Colored (1995),
#  movieId = 85, title = Angels and Insects (1995),
#  movieId = 86, title = White Squall (1996),
#  movieId = 87, title = Dunston Checks In (1996),
#  movieId = 88, title = Black Sheep (1996),
#  movieId = 89, title = Nick of Time (1995),
#  movieId = 92, title = Mary Reilly (1996),
#  movieId = 93, title = Vampire in Brooklyn (1995),
#  movieId = 94, title = Beautiful Girls (1996),
#  movieId = 95, title = Broken Arrow (1996),
#  movieId = 96, title = In the Bleak Midwinter (1995),
#  movieId = 97, title = Hate (Haine, La) (1995),
#  movieId = 99, title = Heidi Fleiss: Hollywood Madam (1995),
#  movieId = 100, title = City Hall (1996),
#  movieId = 101, title = Bottle Rocket (1996),
#  movieId = 102, title = Mr. Wrong (1996),
#  movieId = 103, title = Unforgettable (1996),
#  movieId = 104, title = Happy Gilmore (1996),
#  movieId = 105, title = Bridges of Madison County, The (1995),
#  movieId = 106, title = Nobody Loves Me (Keiner liebt mich) (1994),
#  movieId = 107, title = Muppet Treasure Island (1996),
#  movieId = 108, title = Catwalk (1996),
#  movieId = 110, title = Braveheart (1995),
#  movieId = 111, title = Taxi Driver (1976),
#  movieId = 112, title = Rumble in the Bronx (Hont faan kui) (1995),
#  movieId = 113, title = Before and After (1996),
#  movieId = 116, title = Anne Frank Remembered (1995),
#  movieId = 117, title = Young Poisoner's Handbook, The (1995),
#  movieId = 118, title = If Lucy Fell (1996),
#  movieId = 119, title = Steal Big, Steal Little (1995),
#  movieId = 121, title = Boys of St. Vincent, The (1992),
#  movieId = 122, title = Boomerang (1992),
#  movieId = 123, title = Chungking Express (Chung Hing sam lam) (1994),
#  movieId = 125, title = Flirting With Disaster (1996),
#  movieId = 126, title = NeverEnding Story III, The (1994),
#  movieId = 128, title = Jupiter's Wife (1994),
#  movieId = 129, title = Pie in the Sky (1996),
#  movieId = 132, title = Jade (1995),
#  movieId = 135, title = Down Periscope (1996),
#  movieId = 137, title = Man of the Year (1995),
#  movieId = 140, title = Up Close and Personal (1996),
#  movieId = 141, title = Birdcage, The (1996),
#  movieId = 144, title = Brothers McMullen, The (1995),
#  movieId = 145, title = Bad Boys (1995),
#  movieId = 146, title = Amazing Panda Adventure, The (1995),
#  movieId = 147, title = Basketball Diaries, The (1995),
#  movieId = 148, title = Awfully Big Adventure, An (1995),
#  movieId = 149, title = Amateur (1994),
#  movieId = 150, title = Apollo 13 (1995),
#  movieId = 151, title = Rob Roy (1995),
#  movieId = 152, title = Addiction, The (1995),
#  movieId = 153, title = Batman Forever (1995),
#  movieId = 154, title = Beauty of the Day (Belle de jour) (1967),
#  movieId = 155, title = Beyond Rangoon (1995),
#  movieId = 156, title = Blue in the Face (1995),
#  movieId = 157, title = Canadian Bacon (1995),
#  movieId = 158, title = Casper (1995),
#  movieId = 159, title = Clockers (1995),
#  movieId = 160, title = Congo (1995),
#  movieId = 161, title = Crimson Tide (1995),
#  movieId = 162, title = Crumb (1994),
#  movieId = 163, title = Desperado (1995),
#  movieId = 164, title = Devil in a Blue Dress (1995),
#  movieId = 165, title = Die Hard: With a Vengeance (1995),
#  movieId = 166, title = Doom Generation, The (1995),
#  movieId = 168, title = First Knight (1995),
#  movieId = 169, title = Free Willy 2: The Adventure Home (1995),
#  movieId = 170, title = Hackers (1995),
#  movieId = 171, title = Jeffrey (1995),
#  movieId = 172, title = Johnny Mnemonic (1995),
#  movieId = 173, title = Judge Dredd (1995),
#  movieId = 174, title = Jury Duty (1995),
#  movieId = 175, title = Kids (1995),
#  movieId = 176, title = Living in Oblivion (1995),
#  movieId = 177, title = Lord of Illusions (1995),
#  movieId = 178, title = Love & Human Remains (1993),
#  movieId = 179, title = Mad Love (1995),
#  movieId = 180, title = Mallrats (1995),
#  movieId = 181, title = Mighty Morphin Power Rangers: The Movie (1995),
#  movieId = 183, title = Mute Witness (1994),
#  movieId = 184, title = Nadja (1994),
#  movieId = 185, title = Net, The (1995),
#  movieId = 186, title = Nine Months (1995),
#  movieId = 187, title = Party Girl (1995),
#  movieId = 188, title = Prophecy, The (1995),
#  movieId = 189, title = Reckless (1995),
#  movieId = 190, title = Safe (1995),
#  movieId = 191, title = Scarlet Letter, The (1995),
#  movieId = 193, title = Showgirls (1995),
#  movieId = 194, title = Smoke (1995),
#  movieId = 195, title = Something to Talk About (1995),
#  movieId = 196, title = Species (1995),
#  movieId = 198, title = Strange Days (1995),
#  movieId = 199, title = Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964),
#  movieId = 201, title = Three Wishes (1995),
#  movieId = 202, title = Total Eclipse (1995),
#  movieId = 203, title = To Wong Foo, Thanks for Everything! Julie Newmar (1995),
#  movieId = 204, title = Under Siege 2: Dark Territory (1995),
#  movieId = 205, title = Unstrung Heroes (1995),
#  movieId = 206, title = Unzipped (1995),
#  movieId = 207, title = Walk in the Clouds, A (1995),
#  movieId = 208, title = Waterworld (1995),
#  movieId = 209, title = White Man's Burden (1995),
#  movieId = 210, title = Wild Bill (1995),
#  movieId = 211, title = Browning Version, The (1994),
#  movieId = 212, title = Bushwhacked (1995),
#  movieId = 213, title = Burnt by the Sun (Utomlyonnye solntsem) (1994),
#  movieId = 214, title = Before the Rain (Pred dozhdot) (1994),
#  movieId = 215, title = Before Sunrise (1995),
#  movieId = 216, title = Billy Madison (1995),
#  movieId = 217, title = Babysitter, The (1995),
#  movieId = 218, title = Boys on the Side (1995),
#  movieId = 219, title = Cure, The (1995),
#  movieId = 220, title = Castle Freak (1995),
#  movieId = 222, title = Circle of Friends (1995),
#  movieId = 223, title = Clerks (1994),
#  movieId = 224, title = Don Juan DeMarco (1995),
#  movieId = 225, title = Disclosure (1994),
#  movieId = 227, title = Drop Zone (1994),
#  movieId = 228, title = Destiny Turns on the Radio (1995),
#  movieId = 229, title = Death and the Maiden (1994),
#  movieId = 230, title = Dolores Claiborne (1995),
#  movieId = 231, title = Dumb & Dumber (Dumb and Dumber) (1994),
#  movieId = 232, title = Eat Drink Man Woman (Yin shi nan nu) (1994),
#  movieId = 233, title = Exotica (1994),
#  movieId = 234, title = Exit to Eden (1994),
#  movieId = 235, title = Ed Wood (1994),
#  movieId = 236, title = French Kiss (1995),
#  movieId = 237, title = Forget Paris (1995),
#  movieId = 238, title = Far From Home: The Adventures of Yellow Dog (1995),
#  movieId = 239, title = Goofy Movie, A (1995),
#  movieId = 240, title = Hideaway (1995),
#  movieId = 241, title = Fluke (1995),
#  movieId = 242, title = Farinelli: il castrato (1994),
#  movieId = 243, title = Gordy (1995),
#  movieId = 246, title = Hoop Dreams (1994),
#  movieId = 247, title = Heavenly Creatures (1994),
#  movieId = 248, title = Houseguest (1994),
#  movieId = 249, title = Immortal Beloved (1994),
#  movieId = 250, title = Heavyweights (Heavy Weights) (1995),
#  movieId = 251, title = Hunted, The (1995),
#  movieId = 252, title = I.Q. (1994),
#  movieId = 253, title = Interview with the Vampire: The Vampire Chronicles (1994),
#  movieId = 254, title = Jefferson in Paris (1995),
#  movieId = 255, title = Jerky Boys, The (1995),
#  movieId = 256, title = Junior (1994),
#  movieId = 257, title = Just Cause (1995),
#  movieId = 258, title = Kid in King Arthur's Court, A (1995),
#  movieId = 259, title = Kiss of Death (1995),
#  movieId = 260, title = Star Wars: Episode IV - A New Hope (1977),
#  movieId = 261, title = Little Women (1994),
#  movieId = 262, title = Little Princess, A (1995),
#  movieId = 263, title = Ladybird Ladybird (1994),
#  movieId = 265, title = Like Water for Chocolate (Como agua para chocolate) (1992),
#  movieId = 266, title = Legends of the Fall (1994),
#  movieId = 267, title = Major Payne (1995),
#  movieId = 269, title = My Crazy Life (Mi vida loca) (1993),
#  movieId = 270, title = Love Affair (1994),
#  movieId = 271, title = Losing Isaiah (1995),
#  movieId = 272, title = Madness of King George, The (1994),
#  movieId = 273, title = Mary Shelley's Frankenstein (Frankenstein) (1994),
#  movieId = 274, title = Man of the House (1995),
#  movieId = 275, title = Mixed Nuts (1994),
#  movieId = 276, title = Milk Money (1994),
#  movieId = 277, title = Miracle on 34th Street (1994),
#  movieId = 278, title = Miami Rhapsody (1995),
#  movieId = 279, title = My Family (1995),
#  movieId = 280, title = Murder in the First (1995),
#  movieId = 281, title = Nobody's Fool (1994),
#  movieId = 282, title = Nell (1994),
#  movieId = 283, title = New Jersey Drive (1995),
#  movieId = 284, title = New York Cop (Nyû Yôku no koppu) (1993),
#  movieId = 285, title = Beyond Bedlam (1993),
#  movieId = 287, title = Nina Takes a Lover (1994),
#  movieId = 288, title = Natural Born Killers (1994),
#  movieId = 289, title = Only You (1994),
#  movieId = 290, title = Once Were Warriors (1994),
#  movieId = 291, title = Poison Ivy II (1996),
#  movieId = 292, title = Outbreak (1995),
#  movieId = 293, title = Léon: The Professional (a.k.a. The Professional) (Léon) (1994),
#  movieId = 294, title = Perez Family, The (1995),
#  movieId = 295, title = Pyromaniac's Love Story, A (1995),
#  movieId = 296, title = Pulp Fiction (1994),
#  movieId = 298, title = Pushing Hands (Tui shou) (1992),
#  movieId = 299, title = Priest (1994),
#  movieId = 300, title = Quiz Show (1994),
#  movieId = 301, title = Picture Bride (Bijo photo) (1994),
#  movieId = 302, title = Queen Margot (Reine Margot, La) (1994),
#  movieId = 303, title = Quick and the Dead, The (1995),
#  movieId = 304, title = Roommates (1995),
#  movieId = 305, title = Ready to Wear (Pret-A-Porter) (1994),
#  movieId = 306, title = Three Colors: Red (Trois couleurs: Rouge) (1994),
#  movieId = 307, title = Three Colors: Blue (Trois couleurs: Bleu) (1993),
#  movieId = 308, title = Three Colors: White (Trzy kolory: Bialy) (1994),
#  movieId = 310, title = Rent-a-Kid (1995),
#  movieId = 311, title = Relative Fear (1994),
#  movieId = 312, title = Stuart Saves His Family (1995),
#  movieId = 313, title = Swan Princess, The (1994),
#  movieId = 314, title = Secret of Roan Inish, The (1994),
#  movieId = 315, title = Specialist, The (1994),
#  movieId = 316, title = Stargate (1994),
#  movieId = 317, title = Santa Clause, The (1994),
#  movieId = 318, title = Shawshank Redemption, The (1994),
#  movieId = 319, title = Shallow Grave (1994),
#  movieId = 320, title = Suture (1993),
#  movieId = 321, title = Strawberry and Chocolate (Fresa y chocolate) (1993),
#  movieId = 322, title = Swimming with Sharks (1995),
#  movieId = 324, title = Sum of Us, The (1994),
#  movieId = 325, title = National Lampoon's Senior Trip (1995),
#  movieId = 326, title = To Live (Huozhe) (1994),
#  movieId = 327, title = Tank Girl (1995),
#  movieId = 328, title = Tales from the Crypt Presents: Demon Knight (1995),
#  movieId = 329, title = Star Trek: Generations (1994),
#  movieId = 330, title = Tales from the Hood (1995),
#  movieId = 331, title = Tom & Viv (1994),
#  movieId = 332, title = Village of the Damned (1995),
#  movieId = 333, title = Tommy Boy (1995),
#  movieId = 334, title = Vanya on 42nd Street (1994),
#  movieId = 335, title = Underneath (1995),
#  movieId = 336, title = Walking Dead, The (1995),
#  movieId = 337, title = What's Eating Gilbert Grape (1993),
#  movieId = 338, title = Virtuosity (1995),
#  movieId = 339, title = While You Were Sleeping (1995),
#  movieId = 340, title = War, The (1994),
#  movieId = 341, title = Double Happiness (1994),
#  movieId = 342, title = Muriel's Wedding (1994),
#  movieId = 343, title = Baby-Sitters Club, The (1995),
#  movieId = 344, title = Ace Ventura: Pet Detective (1994),
#  movieId = 345, title = Adventures of Priscilla, Queen of the Desert, The (1994),
#  movieId = 346, title = Backbeat (1993),
#  movieId = 347, title = Bitter Moon (1992),
#  movieId = 348, title = Bullets Over Broadway (1994),
#  movieId = 349, title = Clear and Present Danger (1994),
#  movieId = 350, title = Client, The (1994),
#  movieId = 351, title = Corrina, Corrina (1994),
#  movieId = 352, title = Crooklyn (1994),
#  movieId = 353, title = Crow, The (1994),
#  movieId = 354, title = Cobb (1994),
#  movieId = 355, title = Flintstones, The (1994),
#  movieId = 356, title = Forrest Gump (1994),
#  movieId = 357, title = Four Weddings and a Funeral (1994),
#  movieId = 358, title = Higher Learning (1995),
#  movieId = 359, title = I Like It Like That (1994),
#  movieId = 360, title = I Love Trouble (1994),
#  movieId = 361, title = It Could Happen to You (1994),
#  movieId = 362, title = Jungle Book, The (1994),
#  movieId = 363, title = Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993),
#  movieId = 364, title = Lion King, The (1994),
#  movieId = 365, title = Little Buddha (1993),
#  movieId = 366, title = Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994),
#  movieId = 367, title = Mask, The (1994),
#  movieId = 368, title = Maverick (1994),
#  movieId = 369, title = Mrs. Parker and the Vicious Circle (1994),
#  movieId = 370, title = Naked Gun 33 1/3: The Final Insult (1994),
#  movieId = 371, title = Paper, The (1994),
#  movieId = 372, title = Reality Bites (1994),
#  movieId = 373, title = Red Rock West (1992),
#  movieId = 374, title = Richie Rich (1994),
#  movieId = 376, title = River Wild, The (1994),
#  movieId = 377, title = Speed (1994),
#  movieId = 378, title = Speechless (1994),
#  movieId = 379, title = Timecop (1994),
#  movieId = 380, title = True Lies (1994),
#  movieId = 381, title = When a Man Loves a Woman (1994),
#  movieId = 382, title = Wolf (1994),
#  movieId = 383, title = Wyatt Earp (1994),
#  movieId = 384, title = Bad Company (1995),
#  movieId = 385, title = Man of No Importance, A (1994),
#  movieId = 386, title = S.F.W. (1994),
#  movieId = 387, title = Low Down Dirty Shame, A (1994),
#  movieId = 388, title = Boys Life (1995),
#  movieId = 389, title = Colonel Chabert, Le (1994),
#  movieId = 390, title = Faster Pussycat! Kill! Kill! (1965),
#  movieId = 391, title = Jason's Lyric (1994),
#  movieId = 393, title = Street Fighter (1994),
#  movieId = 405, title = Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994),
#  movieId = 406, title = Federal Hill (1994),
#  movieId = 407, title = In the Mouth of Madness (1995),
#  movieId = 408, title = 8 Seconds (1994),
#  movieId = 409, title = Above the Rim (1994),
#  movieId = 410, title = Addams Family Values (1993),
#  movieId = 412, title = Age of Innocence, The (1993),
#  movieId = 413, title = Airheads (1994),
#  movieId = 414, title = Air Up There, The (1994),
#  movieId = 415, title = Another Stakeout (1993),
#  movieId = 416, title = Bad Girls (1994),
#  movieId = 417, title = Barcelona (1994),
#  movieId = 418, title = Being Human (1993),
#  movieId = 419, title = Beverly Hillbillies, The (1993),
#  movieId = 420, title = Beverly Hills Cop III (1994),
#  movieId = 421, title = Black Beauty (1994),
#  movieId = 422, title = Blink (1994),
#  movieId = 423, title = Blown Away (1994),
#  movieId = 424, title = Blue Chips (1994),
#  movieId = 425, title = Blue Sky (1994),
#  movieId = 426, title = Body Snatchers (1993),
#  movieId = 427, title = Boxing Helena (1993),
#  movieId = 428, title = Bronx Tale, A (1993),
#  movieId = 429, title = Cabin Boy (1994),
#  movieId = 430, title = Calendar Girl (1993),
#  movieId = 431, title = Carlito's Way (1993),
#  movieId = 432, title = City Slickers II: The Legend of Curly's Gold (1994),
#  movieId = 433, title = Clean Slate (1994),
#  movieId = 434, title = Cliffhanger (1993),
#  movieId = 435, title = Coneheads (1993),
#  movieId = 436, title = Color of Night (1994),
#  movieId = 437, title = Cops and Robbersons (1994),
#  movieId = 438, title = Cowboy Way, The (1994),
#  movieId = 440, title = Dave (1993),
#  movieId = 441, title = Dazed and Confused (1993),
#  movieId = 442, title = Demolition Man (1993),
#  movieId = 444, title = Even Cowgirls Get the Blues (1993),
#  movieId = 445, title = Fatal Instinct (1993),
#  movieId = 446, title = Farewell My Concubine (Ba wang bie ji) (1993),
#  movieId = 448, title = Fearless (1993),
#  movieId = 449, title = Fear of a Black Hat (1994),
#  movieId = 450, title = With Honors (1994),
#  movieId = 451, title = Flesh and Bone (1993),
#  movieId = 452, title = Widows' Peak (1994),
#  movieId = 453, title = For Love or Money (1993),
#  movieId = 454, title = Firm, The (1993),
#  movieId = 455, title = Free Willy (1993),
#  movieId = 456, title = Fresh (1994),
#  movieId = 457, title = Fugitive, The (1993),
#  movieId = 458, title = Geronimo: An American Legend (1993),
#  movieId = 459, title = Getaway, The (1994),
#  movieId = 460, title = Getting Even with Dad (1994),
#  movieId = 461, title = Go Fish (1994),
#  movieId = 464, title = Hard Target (1993),
#  movieId = 466, title = Hot Shots! Part Deux (1993),
#  movieId = 467, title = Live Nude Girls (1995),
#  movieId = 468, title = Englishman Who Went Up a Hill But Came Down a Mountain, The (1995),
#  movieId = 469, title = House of the Spirits, The (1993),
#  movieId = 470, title = House Party 3 (1994),
#  movieId = 471, title = Hudsucker Proxy, The (1994),
#  movieId = 472, title = I'll Do Anything (1994),
#  movieId = 473, title = In the Army Now (1994),
#  movieId = 474, title = In the Line of Fire (1993),
#  movieId = 475, title = In the Name of the Father (1993),
#  movieId = 476, title = Inkwell, The (1994),
#  movieId = 477, title = What's Love Got to Do with It? (1993),
#  movieId = 478, title = Jimmy Hollywood (1994),
#  movieId = 479, title = Judgment Night (1993),
#  movieId = 480, title = Jurassic Park (1993),
#  movieId = 481, title = Kalifornia (1993),
#  movieId = 482, title = Killing Zoe (1994),
#  movieId = 484, title = Lassie (1994),
#  movieId = 485, title = Last Action Hero (1993),
#  movieId = 486, title = Life with Mikey (1993),
#  movieId = 487, title = Lightning Jack (1994),
#  movieId = 488, title = M. Butterfly (1993),
#  movieId = 489, title = Made in America (1993),
#  movieId = 490, title = Malice (1993),
#  movieId = 491, title = Man Without a Face, The (1993),
#  movieId = 492, title = Manhattan Murder Mystery (1993),
#  movieId = 493, title = Menace II Society (1993),
#  movieId = 494, title = Executive Decision (1996),
#  movieId = 495, title = In the Realm of the Senses (Ai no corrida) (1976),
#  movieId = 496, title = What Happened Was... (1994),
#  movieId = 497, title = Much Ado About Nothing (1993),
#  movieId = 499, title = Mr. Wonderful (1993),
#  movieId = 500, title = Mrs. Doubtfire (1993),
#  movieId = 501, title = Naked (1993),
#  movieId = 502, title = Next Karate Kid, The (1994),
#  movieId = 504, title = No Escape (1994),
#  movieId = 505, title = North (1994),
#  movieId = 506, title = Orlando (1992),
#  movieId = 507, title = Perfect World, A (1993),
#  movieId = 508, title = Philadelphia (1993),
#  movieId = 509, title = Piano, The (1993),
#  movieId = 510, title = Poetic Justice (1993),
#  movieId = 511, title = Program, The (1993),
#  movieId = 512, title = Puppet Masters, The (1994),
#  movieId = 513, title = Radioland Murders (1994),
#  movieId = 514, title = Ref, The (1994),
#  movieId = 515, title = Remains of the Day, The (1993),
#  movieId = 516, title = Renaissance Man (1994),
#  movieId = 517, title = Rising Sun (1993),
#  movieId = 518, title = Road to Wellville, The (1994),
#  movieId = 519, title = RoboCop 3 (1993),
#  movieId = 520, title = Robin Hood: Men in Tights (1993),
#  movieId = 521, title = Romeo Is Bleeding (1993),
#  movieId = 522, title = Romper Stomper (1992),
#  movieId = 523, title = Ruby in Paradise (1993),
#  movieId = 524, title = Rudy (1993),
#  movieId = 526, title = Savage Nights (Nuits fauves, Les) (1992),
#  movieId = 527, title = Schindler's List (1993),
#  movieId = 528, title = Scout, The (1994),
#  movieId = 529, title = Searching for Bobby Fischer (1993),
#  movieId = 531, title = Secret Garden, The (1993),
#  movieId = 532, title = Serial Mom (1994),
#  movieId = 533, title = Shadow, The (1994),
#  movieId = 534, title = Shadowlands (1993),
#  movieId = 535, title = Short Cuts (1993),
#  movieId = 536, title = Simple Twist of Fate, A (1994),
#  movieId = 537, title = Sirens (1994),
#  movieId = 538, title = Six Degrees of Separation (1993),
#  movieId = 539, title = Sleepless in Seattle (1993),
#  movieId = 540, title = Sliver (1993),
#  movieId = 541, title = Blade Runner (1982),
#  movieId = 542, title = Son in Law (1993),
#  movieId = 543, title = So I Married an Axe Murderer (1993),
#  movieId = 544, title = Striking Distance (1993),
#  movieId = 546, title = Super Mario Bros. (1993),
#  movieId = 547, title = Surviving the Game (1994),
#  movieId = 548, title = Terminal Velocity (1994),
#  movieId = 549, title = Thirty-Two Short Films About Glenn Gould (1993),
#  movieId = 550, title = Threesome (1994),
#  movieId = 551, title = Nightmare Before Christmas, The (1993),
#  movieId = 552, title = Three Musketeers, The (1993),
#  movieId = 553, title = Tombstone (1993),
#  movieId = 555, title = True Romance (1993),
#  movieId = 556, title = War Room, The (1993),
#  movieId = 558, title = Pagemaster, The (1994),
#  movieId = 562, title = Welcome to the Dollhouse (1995),
#  movieId = 563, title = Germinal (1993),
#  movieId = 564, title = Chasers (1994),
#  movieId = 567, title = Kika (1993),
#  movieId = 568, title = Bhaji on the Beach (1993),
#  movieId = 569, title = Little Big League (1994),
#  movieId = 573, title = Ciao, Professore! (Io speriamo che me la cavo) (1992),
#  movieId = 574, title = Spanking the Monkey (1994),
#  movieId = 575, title = Little Rascals, The (1994),
#  movieId = 577, title = Andre (1994),
#  movieId = 579, title = Escort, The (Scorta, La) (1993),
#  movieId = 580, title = Princess Caraboo (1994),
#  movieId = 581, title = Celluloid Closet, The (1995),
#  movieId = 583, title = Dear Diary (Caro Diario) (1994),
#  movieId = 585, title = Brady Bunch Movie, The (1995),
#  movieId = 586, title = Home Alone (1990),
#  movieId = 587, title = Ghost (1990),
#  movieId = 588, title = Aladdin (1992),
#  movieId = 589, title = Terminator 2: Judgment Day (1991),
#  movieId = 590, title = Dances with Wolves (1990),
#  movieId = 592, title = Batman (1989),
#  movieId = 593, title = Silence of the Lambs, The (1991),
#  movieId = 594, title = Snow White and the Seven Dwarfs (1937),
#  movieId = 595, title = Beauty and the Beast (1991),
#  movieId = 596, title = Pinocchio (1940),
#  movieId = 597, title = Pretty Woman (1990),
#  movieId = 599, title = Wild Bunch, The (1969),
#  movieId = 600, title = Love and a .45 (1994),
#  movieId = 602, title = Great Day in Harlem, A (1994),
#  movieId = 605, title = One Fine Day (1996),
#  movieId = 606, title = Candyman: Farewell to the Flesh (1995),
#  movieId = 608, title = Fargo (1996),
#  movieId = 609, title = Homeward Bound II: Lost in San Francisco (1996),
#  movieId = 610, title = Heavy Metal (1981),
#  movieId = 611, title = Hellraiser: Bloodline (1996),
#  movieId = 612, title = Pallbearer, The (1996),
#  movieId = 613, title = Jane Eyre (1996),
#  movieId = 615, title = Bread and Chocolate (Pane e cioccolata) (1973),
#  movieId = 616, title = Aristocats, The (1970),
#  movieId = 617, title = Flower of My Secret, The (La flor de mi secreto) (1995),
#  movieId = 618, title = Two Much (1995),
#  movieId = 619, title = Ed (1996),
#  movieId = 626, title = Thin Line Between Love and Hate, A (1996),
#  movieId = 627, title = Last Supper, The (1995),
#  movieId = 628, title = Primal Fear (1996),
#  movieId = 631, title = All Dogs Go to Heaven 2 (1996),
#  movieId = 632, title = Land and Freedom (Tierra y libertad) (1995),
#  movieId = 633, title = Denise Calls Up (1995),
#  movieId = 634, title = Theodore Rex (1995),
#  movieId = 635, title = Family Thing, A (1996),
#  movieId = 636, title = Frisk (1995),
#  movieId = 637, title = Sgt. Bilko (1996),
#  movieId = 638, title = Jack and Sarah (1995),
#  movieId = 639, title = Girl 6 (1996),
#  movieId = 640, title = Diabolique (1996),
#  movieId = 645, title = Nelly & Monsieur Arnaud (1995),
#  movieId = 647, title = Courage Under Fire (1996),
#  movieId = 648, title = Mission: Impossible (1996),
#  movieId = 649, title = Cold Fever (Á köldum klaka) (1995),
#  movieId = 650, title = Moll Flanders (1996),
#  movieId = 653, title = Dragonheart (1996),
#  movieId = 656, title = Eddie (1996),
#  movieId = 661, title = James and the Giant Peach (1996),
#  movieId = 662, title = Fear (1996),
#  movieId = 663, title = Kids in the Hall: Brain Candy (1996),
#  movieId = 665, title = Underground (1995),
#  movieId = 667, title = Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996),
#  movieId = 668, title = Song of the Little Road (Pather Panchali) (1955),
#  movieId = 670, title = World of Apu, The (Apur Sansar) (1959),
#  movieId = 671, title = Mystery Science Theater 3000: The Movie (1996),
#  movieId = 673, title = Space Jam (1996),
#  movieId = 674, title = Barbarella (1968),
#  movieId = 678, title = Some Folks Call It a Sling Blade (1993),
#  movieId = 679, title = Run of the Country, The (1995),
#  movieId = 680, title = Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965),
#  movieId = 685, title = It's My Party (1996),
#  movieId = 688, title = Operation Dumbo Drop (1995),
#  movieId = 691, title = Mrs. Winterbourne (1996),
#  movieId = 692, title = Solo (1996),
#  movieId = 694, title = Substitute, The (1996),
#  movieId = 695, title = True Crime (1996),
#  movieId = 697, title = Feeling Minnesota (1996),
#  movieId = 698, title = Delta of Venus (1995),
#  movieId = 700, title = Angus (1995),
#  movieId = 703, title = Boys (1996),
#  movieId = 704, title = Quest, The (1996),
#  movieId = 706, title = Sunset Park (1996),
#  movieId = 707, title = Mulholland Falls (1996),
#  movieId = 708, title = Truth About Cats & Dogs, The (1996),
#  movieId = 709, title = Oliver & Company (1988),
#  movieId = 710, title = Celtic Pride (1996),
#  movieId = 711, title = Flipper (1996),
#  movieId = 714, title = Dead Man (1995),
#  movieId = 715, title = Horseman on the Roof, The (Hussard sur le toit, Le) (1995),
#  movieId = 718, title = Visitors, The (Visiteurs, Les) (1993),
#  movieId = 719, title = Multiplicity (1996),
#  movieId = 720, title = Wallace & Gromit: The Best of Aardman Animation (1996),
#  movieId = 722, title = Haunted World of Edward D. Wood Jr., The (1996),
#  movieId = 724, title = Craft, The (1996),
#  movieId = 725, title = Great White Hype, The (1996),
#  movieId = 726, title = Last Dance (1996),
#  movieId = 728, title = Cold Comfort Farm (1995),
#  movieId = 731, title = Heaven's Prisoners (1996),
#  movieId = 733, title = Rock, The (1996),
#  movieId = 735, title = Cemetery Man (Dellamorte Dellamore) (1994),
#  movieId = 736, title = Twister (1996),
#  movieId = 737, title = Barb Wire (1996),
#  movieId = 741, title = Ghost in the Shell (Kôkaku kidôtai) (1995),
#  movieId = 742, title = Thinner (1996),
#  movieId = 743, title = Spy Hard (1996),
#  movieId = 745, title = Wallace & Gromit: A Close Shave (1995),
#  movieId = 747, title = Stupids, The (1996),
#  movieId = 748, title = Arrival, The (1996),
#  movieId = 750, title = Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964),
#  movieId = 757, title = Ashes of Time (Dung che sai duk) (1994),
#  movieId = 759, title = Maya Lin: A Strong Clear Vision (1994),
#  movieId = 760, title = Stalingrad (1993),
#  movieId = 761, title = Phantom, The (1996),
#  movieId = 762, title = Striptease (1996),
#  movieId = 764, title = Heavy (1995),
#  movieId = 765, title = Jack (1996),
#  movieId = 766, title = I Shot Andy Warhol (1996),
#  movieId = 773, title = Touki Bouki (1973),
#  movieId = 775, title = Spirits of the Dead (1968),
#  movieId = 778, title = Trainspotting (1996),
#  movieId = 779, title = 'Til There Was You (1997),
#  movieId = 780, title = Independence Day (a.k.a. ID4) (1996),
#  movieId = 781, title = Stealing Beauty (1996),
#  movieId = 782, title = Fan, The (1996),
#  movieId = 783, title = Hunchback of Notre Dame, The (1996),
#  movieId = 784, title = Cable Guy, The (1996),
#  movieId = 785, title = Kingpin (1996),
#  movieId = 786, title = Eraser (1996),
#  movieId = 788, title = Nutty Professor, The (1996),
#  movieId = 790, title = Unforgettable Summer, An (Un été inoubliable) (1994),
#  movieId = 791, title = Last Klezmer: Leopold Kozlowski, His Life and Music, The (1994),
#  movieId = 795, title = Somebody to Love (1994),
#  movieId = 798, title = Daylight (1996),
#  movieId = 799, title = Frighteners, The (1996),
#  movieId = 800, title = Lone Star (1996),
#  movieId = 801, title = Harriet the Spy (1996),
#  movieId = 802, title = Phenomenon (1996),
#  movieId = 803, title = Walking and Talking (1996),
#  movieId = 804, title = She's the One (1996),
#  movieId = 805, title = Time to Kill, A (1996),
#  movieId = 806, title = American Buffalo (1996),
#  movieId = 808, title = Alaska (1996),
#  movieId = 809, title = Fled (1996),
#  movieId = 810, title = Kazaam (1996),
#  movieId = 813, title = Larger Than Life (1996),
#  movieId = 818, title = Very Brady Sequel, A (1996),
#  movieId = 823, title = Collector, The (La collectionneuse) (1967),
#  movieId = 824, title = Kaspar Hauser (1993),
#  movieId = 828, title = Adventures of Pinocchio, The (1996),
#  movieId = 829, title = Joe's Apartment (1996),
#  movieId = 830, title = First Wives Club, The (1996),
#  movieId = 832, title = Ransom (1996),
#  movieId = 833, title = High School High (1996),
#  movieId = 835, title = Foxfire (1996),
#  movieId = 836, title = Chain Reaction (1996),
#  movieId = 837, title = Matilda (1996),
#  movieId = 838, title = Emma (1996),
#  movieId = 839, title = Crow: City of Angels, The (1996),
#  movieId = 840, title = House Arrest (1996),
#  movieId = 841, title = Eyes Without a Face (Yeux sans visage, Les) (1959),
#  movieId = 842, title = Tales from the Crypt Presents: Bordello of Blood (1996),
#  movieId = 848, title = Spitfire Grill, The (1996),
#  movieId = 849, title = Escape from L.A. (1996),
#  movieId = 851, title = Basquiat (1996),
#  movieId = 852, title = Tin Cup (1996),
#  movieId = 858, title = Godfather, The (1972),
#  movieId = 861, title = Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992),
#  movieId = 866, title = Bound (1996),
#  movieId = 867, title = Carpool (1996),
#  movieId = 869, title = Kansas City (1996),
#  movieId = 870, title = Gone Fishin' (1997),
#  movieId = 875, title = Nothing to Lose (1994),
#  movieId = 876, title = Supercop 2 (Project S) (Chao ji ji hua) (1993),
#  movieId = 879, title = Relic, The (1997),
#  movieId = 880, title = Island of Dr. Moreau, The (1996),
#  movieId = 881, title = First Kid (1996),
#  movieId = 882, title = Trigger Effect, The (1996),
#  movieId = 885, title = Bogus (1996),
#  movieId = 886, title = Bulletproof (1996),
#  movieId = 888, title = Land Before Time III: The Time of the Great Giving (1995),
#  movieId = 889, title = 1-900 (06) (1994),
#  movieId = 891, title = Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995),
#  movieId = 892, title = Twelfth Night (1996),
#  movieId = 893, title = Mother Night (1996),
#  movieId = 896, title = Wild Reeds (Les roseaux sauvages) (1994),
#  movieId = 897, title = For Whom the Bell Tolls (1943),
#  movieId = 898, title = Philadelphia Story, The (1940),
#  movieId = 899, title = Singin' in the Rain (1952),
#  movieId = 900, title = American in Paris, An (1951),
#  movieId = 901, title = Funny Face (1957),
#  movieId = 902, title = Breakfast at Tiffany's (1961),
#  movieId = 903, title = Vertigo (1958),
#  movieId = 904, title = Rear Window (1954),
#  movieId = 905, title = It Happened One Night (1934),
#  movieId = 906, title = Gaslight (1944),
#  movieId = 907, title = Gay Divorcee, The (1934),
#  movieId = 908, title = North by Northwest (1959),
#  movieId = 909, title = Apartment, The (1960),
#  movieId = 910, title = Some Like It Hot (1959),
#  movieId = 911, title = Charade (1963),
#  movieId = 912, title = Casablanca (1942),
#  movieId = 913, title = Maltese Falcon, The (1941),
#  movieId = 914, title = My Fair Lady (1964),
#  movieId = 915, title = Sabrina (1954),
#  movieId = 916, title = Roman Holiday (1953),
#  movieId = 917, title = Little Princess, The (1939),
#  movieId = 918, title = Meet Me in St. Louis (1944),
#  movieId = 919, title = Wizard of Oz, The (1939),
#  movieId = 920, title = Gone with the Wind (1939),
#  movieId = 921, title = My Favorite Year (1982),
#  movieId = 922, title = Sunset Blvd. (a.k.a. Sunset Boulevard) (1950),
#  movieId = 923, title = Citizen Kane (1941),
#  movieId = 924, title = 2001: A Space Odyssey (1968),
#  movieId = 926, title = All About Eve (1950),
#  movieId = 927, title = Women, The (1939),
#  movieId = 928, title = Rebecca (1940),
#  movieId = 929, title = Foreign Correspondent (1940),
#  movieId = 930, title = Notorious (1946),
#  movieId = 931, title = Spellbound (1945),
#  movieId = 932, title = Affair to Remember, An (1957),
#  movieId = 933, title = To Catch a Thief (1955),
#  movieId = 934, title = Father of the Bride (1950),
#  movieId = 935, title = Band Wagon, The (1953),
#  movieId = 936, title = Ninotchka (1939),
#  movieId = 937, title = Love in the Afternoon (1957),
#  movieId = 938, title = Gigi (1958),
#  movieId = 940, title = Adventures of Robin Hood, The (1938),
#  movieId = 941, title = Mark of Zorro, The (1940),
#  movieId = 942, title = Laura (1944),
#  movieId = 943, title = Ghost and Mrs. Muir, The (1947),
#  movieId = 944, title = Lost Horizon (1937),
#  movieId = 945, title = Top Hat (1935),
#  movieId = 946, title = To Be or Not to Be (1942),
#  movieId = 947, title = My Man Godfrey (1936),
#  movieId = 948, title = Giant (1956),
#  movieId = 949, title = East of Eden (1955),
#  movieId = 950, title = Thin Man, The (1934),
#  movieId = 951, title = His Girl Friday (1940),
#  movieId = 952, title = Around the World in 80 Days (1956),
#  movieId = 953, title = It's a Wonderful Life (1946),
#  movieId = 954, title = Mr. Smith Goes to Washington (1939),
#  movieId = 955, title = Bringing Up Baby (1938),
#  movieId = 956, title = Penny Serenade (1941),
#  movieId = 959, title = Of Human Bondage (1934),
#  movieId = 961, title = Little Lord Fauntleroy (1936),
#  movieId = 963, title = Inspector General, The (1949),
#  movieId = 965, title = 39 Steps, The (1935),
#  movieId = 968, title = Night of the Living Dead (1968),
#  movieId = 969, title = African Queen, The (1951),
#  movieId = 970, title = Beat the Devil (1953),
#  movieId = 971, title = Cat on a Hot Tin Roof (1958),
#  movieId = 973, title = Meet John Doe (1941),
#  movieId = 976, title = Farewell to Arms, A (1932),
#  movieId = 979, title = Nothing Personal (1995),
#  movieId = 981, title = Dangerous Ground (1997),
#  movieId = 982, title = Picnic (1955),
#  movieId = 984, title = Pompatus of Love, The (1996),
#  movieId = 986, title = Fly Away Home (1996),
#  movieId = 987, title = Bliss (1997),
#  movieId = 988, title = Grace of My Heart (1996),
#  movieId = 990, title = Maximum Risk (1996),
#  movieId = 991, title = Michael Collins (1996),
#  movieId = 993, title = Infinity (1996),
#  movieId = 994, title = Big Night (1996),
#  movieId = 996, title = Last Man Standing (1996),
#  movieId = 998, title = Set It Off (1996),
#  movieId = 999, title = 2 Days in the Valley (1996),
#  movieId = 1003, title = Extreme Measures (1996),
#  movieId = 1004, title = Glimmer Man, The (1996),
#  movieId = 1005, title = D3: The Mighty Ducks (1996),
#  movieId = 1006, title = Chamber, The (1996),
#  movieId = 1007, title = Apple Dumpling Gang, The (1975),
#  movieId = 1008, title = Davy Crockett, King of the Wild Frontier (1955),
#  movieId = 1009, title = Escape to Witch Mountain (1975),
#  movieId = 1010, title = Love Bug, The (1969),
#  movieId = 1011, title = Herbie Rides Again (1974),
#  movieId = 1012, title = Old Yeller (1957),
#  movieId = 1013, title = Parent Trap, The (1961),
#  movieId = 1014, title = Pollyanna (1960),
#  movieId = 1015, title = Homeward Bound: The Incredible Journey (1993),
#  movieId = 1016, title = Shaggy Dog, The (1959),
#  movieId = 1017, title = Swiss Family Robinson (1960),
#  movieId = 1018, title = That Darn Cat! (1965),
#  movieId = 1019, title = 20,000 Leagues Under the Sea (1954),
#  movieId = 1020, title = Cool Runnings (1993),
#  movieId = 1021, title = Angels in the Outfield (1994),
#  movieId = 1022, title = Cinderella (1950),
#  movieId = 1023, title = Winnie the Pooh and the Blustery Day (1968),
#  movieId = 1024, title = Three Caballeros, The (1945),
#  movieId = 1025, title = Sword in the Stone, The (1963),
#  movieId = 1027, title = Robin Hood: Prince of Thieves (1991),
#  movieId = 1028, title = Mary Poppins (1964),
#  movieId = 1029, title = Dumbo (1941),
#  movieId = 1030, title = Pete's Dragon (1977),
#  movieId = 1031, title = Bedknobs and Broomsticks (1971),
#  movieId = 1032, title = Alice in Wonderland (1951),
#  movieId = 1033, title = Fox and the Hound, The (1981),
#  movieId = 1034, title = Freeway (1996),
#  movieId = 1035, title = Sound of Music, The (1965),
#  movieId = 1036, title = Die Hard (1988),
#  movieId = 1037, title = Lawnmower Man, The (1992),
#  movieId = 1040, title = Secret Agent, The (1996),
#  movieId = 1041, title = Secrets & Lies (1996),
#  movieId = 1042, title = That Thing You Do! (1996),
#  movieId = 1043, title = To Gillian on Her 37th Birthday (1996),
#  movieId = 1046, title = Beautiful Thing (1996),
#  movieId = 1047, title = Long Kiss Goodnight, The (1996),
#  movieId = 1049, title = Ghost and the Darkness, The (1996),
#  movieId = 1050, title = Looking for Richard (1996),
#  movieId = 1051, title = Trees Lounge (1996),
#  movieId = 1053, title = Normal Life (1996),
#  movieId = 1054, title = Get on the Bus (1996),
#  movieId = 1055, title = Shadow Conspiracy (1997),
#  movieId = 1056, title = Jude (1996),
#  movieId = 1057, title = Everyone Says I Love You (1996),
#  movieId = 1059, title = William Shakespeare's Romeo + Juliet (1996),
#  movieId = 1060, title = Swingers (1996),
#  movieId = 1061, title = Sleepers (1996),
#  movieId = 1064, title = Aladdin and the King of Thieves (1996),
#  movieId = 1066, title = Shall We Dance (1937),
#  movieId = 1068, title = Crossfire (1947),
#  movieId = 1073, title = Willy Wonka & the Chocolate Factory (1971),
#  movieId = 1076, title = Innocents, The (1961),
#  movieId = 1077, title = Sleeper (1973),
#  movieId = 1078, title = Bananas (1971),
#  movieId = 1079, title = Fish Called Wanda, A (1988),
#  movieId = 1080, title = Monty Python's Life of Brian (1979),
#  movieId = 1081, title = Victor/Victoria (1982),
#  movieId = 1082, title = Candidate, The (1972),
#  movieId = 1083, title = Great Race, The (1965),
#  movieId = 1084, title = Bonnie and Clyde (1967),
#  movieId = 1085, title = Old Man and the Sea, The (1958),
#  movieId = 1086, title = Dial M for Murder (1954),
#  movieId = 1088, title = Dirty Dancing (1987),
#  movieId = 1089, title = Reservoir Dogs (1992),
#  movieId = 1090, title = Platoon (1986),
#  movieId = 1091, title = Weekend at Bernie's (1989),
#  movieId = 1092, title = Basic Instinct (1992),
#  movieId = 1093, title = Doors, The (1991),
#  movieId = 1094, title = Crying Game, The (1992),
#  movieId = 1095, title = Glengarry Glen Ross (1992),
#  movieId = 1096, title = Sophie's Choice (1982),
#  movieId = 1097, title = E.T. the Extra-Terrestrial (1982),
#  movieId = 1099, title = Christmas Carol, A (1938),
#  movieId = 1100, title = Days of Thunder (1990),
#  movieId = 1101, title = Top Gun (1986),
#  movieId = 1103, title = Rebel Without a Cause (1955),
#  movieId = 1104, title = Streetcar Named Desire, A (1951),
#  movieId = 1105, title = Children of the Corn IV: The Gathering (1996),
#  movieId = 1107, title = Loser (1991),
#  movieId = 1111, title = Microcosmos (Microcosmos: Le peuple de l'herbe) (1996),
#  movieId = 1112, title = Palookaville (1996),
#  movieId = 1114, title = Funeral, The (1996),
#  movieId = 1116, title = Single Girl, A (Fille seule, La) (1995),
#  movieId = 1117, title = Eighth Day, The (Huitième jour, Le) (1996),
#  movieId = 1119, title = Drunks (1995),
#  movieId = 1120, title = People vs. Larry Flynt, The (1996),
#  movieId = 1121, title = Glory Daze (1995),
#  movieId = 1123, title = Perfect Candidate, A (1996),
#  movieId = 1124, title = On Golden Pond (1981),
#  movieId = 1125, title = Return of the Pink Panther, The (1975),
#  movieId = 1126, title = Drop Dead Fred (1991),
#  movieId = 1127, title = Abyss, The (1989),
#  movieId = 1128, title = Fog, The (1980),
#  movieId = 1129, title = Escape from New York (1981),
#  movieId = 1130, title = Howling, The (1980),
#  movieId = 1131, title = Jean de Florette (1986),
#  movieId = 1132, title = Manon of the Spring (Manon des sources) (1986),
#  movieId = 1135, title = Private Benjamin (1980),
#  movieId = 1136, title = Monty Python and the Holy Grail (1975),
#  movieId = 1137, title = Hustler White (1996),
#  movieId = 1140, title = Entertaining Angels: The Dorothy Day Story (1996),
#  movieId = 1144, title = Line King: The Al Hirschfeld Story, The (1996),
#  movieId = 1147, title = When We Were Kings (1996),
#  movieId = 1148, title = Wallace & Gromit: The Wrong Trousers (1993),
#  movieId = 1150, title = Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982),
#  movieId = 1151, title = Lesson Faust (1994),
#  movieId = 1156, title = Children Are Watching Us, The (Bambini ci guardano, I) (1944),
#  movieId = 1161, title = Tin Drum, The (Blechtrommel, Die) (1979),
#  movieId = 1162, title = Ruling Class, The (1972),
#  movieId = 1163, title = Mina Tannenbaum (1994),
#  movieId = 1167, title = Dear God (1996),
#  movieId = 1170, title = Best of the Best 3: No Turning Back (1995),
#  movieId = 1171, title = Bob Roberts (1992),
#  movieId = 1172, title = Cinema Paradiso (Nuovo cinema Paradiso) (1989),
#  movieId = 1173, title = Cook the Thief His Wife & Her Lover, The (1989),
#  movieId = 1175, title = Delicatessen (1991),
#  movieId = 1176, title = Double Life of Veronique, The (Double Vie de Véronique, La) (1991),
#  movieId = 1177, title = Enchanted April (1992),
#  movieId = 1178, title = Paths of Glory (1957),
#  movieId = 1179, title = Grifters, The (1990),
#  movieId = 1180, title = Hear My Song (1991),
#  movieId = 1183, title = English Patient, The (1996),
#  movieId = 1184, title = Mediterraneo (1991),
#  movieId = 1185, title = My Left Foot (1989),
#  movieId = 1186, title = Sex, Lies, and Videotape (1989),
#  movieId = 1187, title = Passion Fish (1992),
#  movieId = 1188, title = Strictly Ballroom (1992),
#  movieId = 1189, title = Thin Blue Line, The (1988),
#  movieId = 1190, title = Tie Me Up! Tie Me Down! (¡Átame!) (1990),
#  movieId = 1191, title = Madonna: Truth or Dare (1991),
#  movieId = 1192, title = Paris Is Burning (1990),
#  movieId = 1193, title = One Flew Over the Cuckoo's Nest (1975),
#  movieId = 1194, title = Cheech and Chong's Up in Smoke (1978),
#  movieId = 1196, title = Star Wars: Episode V - The Empire Strikes Back (1980),
#  movieId = 1197, title = Princess Bride, The (1987),
#  movieId = 1198, title = Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981),
#  movieId = 1199, title = Brazil (1985),
#  movieId = 1200, title = Aliens (1986),
#  movieId = 1201, title = Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966),
#  movieId = 1202, title = Withnail & I (1987),
#  movieId = 1203, title = 12 Angry Men (1957),
#  movieId = 1204, title = Lawrence of Arabia (1962),
#  movieId = 1206, title = Clockwork Orange, A (1971),
#  movieId = 1207, title = To Kill a Mockingbird (1962),
#  movieId = 1208, title = Apocalypse Now (1979),
#  movieId = 1209, title = Once Upon a Time in the West (C'era una volta il West) (1968),
#  movieId = 1210, title = Star Wars: Episode VI - Return of the Jedi (1983),
#  movieId = 1211, title = Wings of Desire (Himmel über Berlin, Der) (1987),
#  movieId = 1212, title = Third Man, The (1949),
#  movieId = 1213, title = Goodfellas (1990),
#  movieId = 1214, title = Alien (1979),
#  movieId = 1215, title = Army of Darkness (1993),
#  movieId = 1216, title = Big Blue, The (Grand bleu, Le) (1988),
#  movieId = 1217, title = Ran (1985),
#  movieId = 1218, title = Killer, The (Die xue shuang xiong) (1989),
#  movieId = 1219, title = Psycho (1960),
#  movieId = 1220, title = Blues Brothers, The (1980),
#  movieId = 1221, title = Godfather: Part II, The (1974),
#  movieId = 1222, title = Full Metal Jacket (1987),
#  movieId = 1223, title = Grand Day Out with Wallace and Gromit, A (1989),
#  movieId = 1224, title = Henry V (1989),
#  movieId = 1225, title = Amadeus (1984),
#  movieId = 1226, title = Quiet Man, The (1952),
#  movieId = 1227, title = Once Upon a Time in America (1984),
#  movieId = 1228, title = Raging Bull (1980),
#  movieId = 1230, title = Annie Hall (1977),
#  movieId = 1231, title = Right Stuff, The (1983),
#  movieId = 1232, title = Stalker (1979),
#  movieId = 1233, title = Boot, Das (Boat, The) (1981),
#  movieId = 1234, title = Sting, The (1973),
#  movieId = 1235, title = Harold and Maude (1971),
#  movieId = 1236, title = Trust (1990),
#  movieId = 1237, title = Seventh Seal, The (Sjunde inseglet, Det) (1957),
#  movieId = 1238, title = Local Hero (1983),
#  movieId = 1240, title = Terminator, The (1984),
#  movieId = 1241, title = Dead Alive (Braindead) (1992),
#  movieId = 1242, title = Glory (1989),
#  movieId = 1243, title = Rosencrantz and Guildenstern Are Dead (1990),
#  movieId = 1244, title = Manhattan (1979),
#  movieId = 1245, title = Miller's Crossing (1990),
#  movieId = 1246, title = Dead Poets Society (1989),
#  movieId = 1247, title = Graduate, The (1967),
#  movieId = 1248, title = Touch of Evil (1958),
#  movieId = 1249, title = Femme Nikita, La (Nikita) (1990),
#  movieId = 1250, title = Bridge on the River Kwai, The (1957),
#  movieId = 1251, title = 8 1/2 (8½) (1963),
#  movieId = 1252, title = Chinatown (1974),
#  movieId = 1253, title = Day the Earth Stood Still, The (1951),
#  movieId = 1254, title = Treasure of the Sierra Madre, The (1948),
#  movieId = 1255, title = Bad Taste (1987),
#  movieId = 1256, title = Duck Soup (1933),
#  movieId = 1257, title = Better Off Dead... (1985),
#  movieId = 1258, title = Shining, The (1980),
#  movieId = 1259, title = Stand by Me (1986),
#  movieId = 1260, title = M (1931),
#  movieId = 1261, title = Evil Dead II (Dead by Dawn) (1987),
#  movieId = 1262, title = Great Escape, The (1963),
#  movieId = 1263, title = Deer Hunter, The (1978),
#  movieId = 1264, title = Diva (1981),
#  movieId = 1265, title = Groundhog Day (1993),
#  movieId = 1266, title = Unforgiven (1992),
#  movieId = 1267, title = Manchurian Candidate, The (1962),
#  movieId = 1268, title = Pump Up the Volume (1990),
#  movieId = 1269, title = Arsenic and Old Lace (1944),
#  movieId = 1270, title = Back to the Future (1985),
#  movieId = 1271, title = Fried Green Tomatoes (1991),
#  movieId = 1272, title = Patton (1970),
#  movieId = 1273, title = Down by Law (1986),
#  movieId = 1274, title = Akira (1988),
#  movieId = 1275, title = Highlander (1986),
#  movieId = 1276, title = Cool Hand Luke (1967),
#  movieId = 1277, title = Cyrano de Bergerac (1990),
#  movieId = 1278, title = Young Frankenstein (1974),
#  movieId = 1279, title = Night on Earth (1991),
#  movieId = 1280, title = Raise the Red Lantern (Da hong deng long gao gao gua) (1991),
#  movieId = 1281, title = Great Dictator, The (1940),
#  movieId = 1282, title = Fantasia (1940),
#  movieId = 1283, title = High Noon (1952),
#  movieId = 1284, title = Big Sleep, The (1946),
#  movieId = 1285, title = Heathers (1989),
#  movieId = 1286, title = Somewhere in Time (1980),
#  movieId = 1287, title = Ben-Hur (1959),
#  movieId = 1288, title = This Is Spinal Tap (1984),
#  movieId = 1289, title = Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983),
#  movieId = 1290, title = Some Kind of Wonderful (1987),
#  movieId = 1291, title = Indiana Jones and the Last Crusade (1989),
#  movieId = 1292, title = Being There (1979),
#  movieId = 1293, title = Gandhi (1982),
#  movieId = 1295, title = Unbearable Lightness of Being, The (1988),
#  movieId = 1296, title = Room with a View, A (1986),
#  movieId = 1297, title = Real Genius (1985),
#  movieId = 1298, title = Pink Floyd: The Wall (1982),
#  movieId = 1299, title = Killing Fields, The (1984),
#  movieId = 1300, title = My Life as a Dog (Mitt liv som hund) (1985),
#  movieId = 1301, title = Forbidden Planet (1956),
#  ...]

# %% [markdown]
# #### Or make a filtered query using filter()

# %%
# SELECT * FROM test_movies WHERE title = 'Mission Impossible';

#session.query(Test_Movies).filter('Mission Impossible')

session.query(Test_Movies).filter(Test_Movies.title.like('Mission Impossible'))

# %% [markdown]
# #### Delete - let's delete some rows from our tables
# - Delete items using delete( )

# %%
row1 = Test_Movies(movieid=999, title='Mission Impossible', genres='Action')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-1cce70c42f09> in <module>
# ----> 1 row1 = Test_Movies(movieid=999, title='Mission Impossible', genres='Action')
#
# <string> in __init__(self, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/state.py in _initialize_instance(*mixed, **kwargs)
#     422         except:
#     423             with util.safe_reraise():
# --> 424                 manager.dispatch.init_failure(self, args, kwargs)
#     425
#     426     def get_history(self, key, passive):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/state.py in _initialize_instance(*mixed, **kwargs)
#     419
#     420         try:
# --> 421             return manager.original_init(*mixed[1:], **kwargs)
#     422         except:
#     423             with util.safe_reraise():
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/ext/declarative/base.py in _declarative_constructor(self, **kwargs)
#     759             raise TypeError(
#     760                 "%r is an invalid keyword argument for %s" %
# --> 761                 (k, cls_.__name__))
#     762         setattr(self, k, kwargs[k])
#     763 _declarative_constructor.__name__ = '__init__'
#
# TypeError: 'movieid' is an invalid keyword argument for Test_Movies

# %%
session.delete(row1)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b7d798020aa9> in <module>
# ----> 1 session.delete(row1)
#       2 session.commit()
#
# NameError: name 'row1' is not defined

# %%
session.query(Test_Movies).all()
# Out:
# 2019-10-02 11:44:02,598 INFO sqlalchemy.engine.base.Engine SELECT test_movies."movieId" AS "test_movies_movieId", test_movies.title AS test_movies_title, test_movies.genres AS test_movies_genres
# FROM test_movies
# 2019-10-02 11:44:02,599 INFO sqlalchemy.engine.base.Engine {}
# [movieId = 1, title = Toy Story (1995),
#  movieId = 2, title = Jumanji (1995),
#  movieId = 3, title = Grumpier Old Men (1995),
#  movieId = 4, title = Waiting to Exhale (1995),
#  movieId = 5, title = Father of the Bride Part II (1995),
#  movieId = 6, title = Heat (1995),
#  movieId = 7, title = Sabrina (1995),
#  movieId = 8, title = Tom and Huck (1995),
#  movieId = 9, title = Sudden Death (1995),
#  movieId = 10, title = GoldenEye (1995),
#  movieId = 11, title = American President, The (1995),
#  movieId = 12, title = Dracula: Dead and Loving It (1995),
#  movieId = 13, title = Balto (1995),
#  movieId = 14, title = Nixon (1995),
#  movieId = 15, title = Cutthroat Island (1995),
#  movieId = 16, title = Casino (1995),
#  movieId = 17, title = Sense and Sensibility (1995),
#  movieId = 18, title = Four Rooms (1995),
#  movieId = 19, title = Ace Ventura: When Nature Calls (1995),
#  movieId = 20, title = Money Train (1995),
#  movieId = 21, title = Get Shorty (1995),
#  movieId = 22, title = Copycat (1995),
#  movieId = 23, title = Assassins (1995),
#  movieId = 24, title = Powder (1995),
#  movieId = 25, title = Leaving Las Vegas (1995),
#  movieId = 26, title = Othello (1995),
#  movieId = 27, title = Now and Then (1995),
#  movieId = 28, title = Persuasion (1995),
#  movieId = 29, title = City of Lost Children, The (Cité des enfants perdus, La) (1995),
#  movieId = 30, title = Shanghai Triad (Yao a yao yao dao waipo qiao) (1995),
#  movieId = 31, title = Dangerous Minds (1995),
#  movieId = 32, title = Twelve Monkeys (a.k.a. 12 Monkeys) (1995),
#  movieId = 34, title = Babe (1995),
#  movieId = 36, title = Dead Man Walking (1995),
#  movieId = 38, title = It Takes Two (1995),
#  movieId = 39, title = Clueless (1995),
#  movieId = 40, title = Cry, the Beloved Country (1995),
#  movieId = 41, title = Richard III (1995),
#  movieId = 42, title = Dead Presidents (1995),
#  movieId = 43, title = Restoration (1995),
#  movieId = 44, title = Mortal Kombat (1995),
#  movieId = 45, title = To Die For (1995),
#  movieId = 46, title = How to Make an American Quilt (1995),
#  movieId = 47, title = Seven (a.k.a. Se7en) (1995),
#  movieId = 48, title = Pocahontas (1995),
#  movieId = 49, title = When Night Is Falling (1995),
#  movieId = 50, title = Usual Suspects, The (1995),
#  movieId = 52, title = Mighty Aphrodite (1995),
#  movieId = 53, title = Lamerica (1994),
#  movieId = 54, title = Big Green, The (1995),
#  movieId = 55, title = Georgia (1995),
#  movieId = 57, title = Home for the Holidays (1995),
#  movieId = 58, title = Postman, The (Postino, Il) (1994),
#  movieId = 60, title = Indian in the Cupboard, The (1995),
#  movieId = 61, title = Eye for an Eye (1996),
#  movieId = 62, title = Mr. Holland's Opus (1995),
#  movieId = 63, title = Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996),
#  movieId = 64, title = Two if by Sea (1996),
#  movieId = 65, title = Bio-Dome (1996),
#  movieId = 66, title = Lawnmower Man 2: Beyond Cyberspace (1996),
#  movieId = 68, title = French Twist (Gazon maudit) (1995),
#  movieId = 69, title = Friday (1995),
#  movieId = 70, title = From Dusk Till Dawn (1996),
#  movieId = 71, title = Fair Game (1995),
#  movieId = 72, title = Kicking and Screaming (1995),
#  movieId = 73, title = Misérables, Les (1995),
#  movieId = 74, title = Bed of Roses (1996),
#  movieId = 75, title = Big Bully (1996),
#  movieId = 76, title = Screamers (1995),
#  movieId = 77, title = Nico Icon (1995),
#  movieId = 78, title = Crossing Guard, The (1995),
#  movieId = 79, title = Juror, The (1996),
#  movieId = 80, title = White Balloon, The (Badkonake sefid) (1995),
#  movieId = 81, title = Things to Do in Denver When You're Dead (1995),
#  movieId = 82, title = Antonia's Line (Antonia) (1995),
#  movieId = 83, title = Once Upon a Time... When We Were Colored (1995),
#  movieId = 85, title = Angels and Insects (1995),
#  movieId = 86, title = White Squall (1996),
#  movieId = 87, title = Dunston Checks In (1996),
#  movieId = 88, title = Black Sheep (1996),
#  movieId = 89, title = Nick of Time (1995),
#  movieId = 92, title = Mary Reilly (1996),
#  movieId = 93, title = Vampire in Brooklyn (1995),
#  movieId = 94, title = Beautiful Girls (1996),
#  movieId = 95, title = Broken Arrow (1996),
#  movieId = 96, title = In the Bleak Midwinter (1995),
#  movieId = 97, title = Hate (Haine, La) (1995),
#  movieId = 99, title = Heidi Fleiss: Hollywood Madam (1995),
#  movieId = 100, title = City Hall (1996),
#  movieId = 101, title = Bottle Rocket (1996),
#  movieId = 102, title = Mr. Wrong (1996),
#  movieId = 103, title = Unforgettable (1996),
#  movieId = 104, title = Happy Gilmore (1996),
#  movieId = 105, title = Bridges of Madison County, The (1995),
#  movieId = 106, title = Nobody Loves Me (Keiner liebt mich) (1994),
#  movieId = 107, title = Muppet Treasure Island (1996),
#  movieId = 108, title = Catwalk (1996),
#  movieId = 110, title = Braveheart (1995),
#  movieId = 111, title = Taxi Driver (1976),
#  movieId = 112, title = Rumble in the Bronx (Hont faan kui) (1995),
#  movieId = 113, title = Before and After (1996),
#  movieId = 116, title = Anne Frank Remembered (1995),
#  movieId = 117, title = Young Poisoner's Handbook, The (1995),
#  movieId = 118, title = If Lucy Fell (1996),
#  movieId = 119, title = Steal Big, Steal Little (1995),
#  movieId = 121, title = Boys of St. Vincent, The (1992),
#  movieId = 122, title = Boomerang (1992),
#  movieId = 123, title = Chungking Express (Chung Hing sam lam) (1994),
#  movieId = 125, title = Flirting With Disaster (1996),
#  movieId = 126, title = NeverEnding Story III, The (1994),
#  movieId = 128, title = Jupiter's Wife (1994),
#  movieId = 129, title = Pie in the Sky (1996),
#  movieId = 132, title = Jade (1995),
#  movieId = 135, title = Down Periscope (1996),
#  movieId = 137, title = Man of the Year (1995),
#  movieId = 140, title = Up Close and Personal (1996),
#  movieId = 141, title = Birdcage, The (1996),
#  movieId = 144, title = Brothers McMullen, The (1995),
#  movieId = 145, title = Bad Boys (1995),
#  movieId = 146, title = Amazing Panda Adventure, The (1995),
#  movieId = 147, title = Basketball Diaries, The (1995),
#  movieId = 148, title = Awfully Big Adventure, An (1995),
#  movieId = 149, title = Amateur (1994),
#  movieId = 150, title = Apollo 13 (1995),
#  movieId = 151, title = Rob Roy (1995),
#  movieId = 152, title = Addiction, The (1995),
#  movieId = 153, title = Batman Forever (1995),
#  movieId = 154, title = Beauty of the Day (Belle de jour) (1967),
#  movieId = 155, title = Beyond Rangoon (1995),
#  movieId = 156, title = Blue in the Face (1995),
#  movieId = 157, title = Canadian Bacon (1995),
#  movieId = 158, title = Casper (1995),
#  movieId = 159, title = Clockers (1995),
#  movieId = 160, title = Congo (1995),
#  movieId = 161, title = Crimson Tide (1995),
#  movieId = 162, title = Crumb (1994),
#  movieId = 163, title = Desperado (1995),
#  movieId = 164, title = Devil in a Blue Dress (1995),
#  movieId = 165, title = Die Hard: With a Vengeance (1995),
#  movieId = 166, title = Doom Generation, The (1995),
#  movieId = 168, title = First Knight (1995),
#  movieId = 169, title = Free Willy 2: The Adventure Home (1995),
#  movieId = 170, title = Hackers (1995),
#  movieId = 171, title = Jeffrey (1995),
#  movieId = 172, title = Johnny Mnemonic (1995),
#  movieId = 173, title = Judge Dredd (1995),
#  movieId = 174, title = Jury Duty (1995),
#  movieId = 175, title = Kids (1995),
#  movieId = 176, title = Living in Oblivion (1995),
#  movieId = 177, title = Lord of Illusions (1995),
#  movieId = 178, title = Love & Human Remains (1993),
#  movieId = 179, title = Mad Love (1995),
#  movieId = 180, title = Mallrats (1995),
#  movieId = 181, title = Mighty Morphin Power Rangers: The Movie (1995),
#  movieId = 183, title = Mute Witness (1994),
#  movieId = 184, title = Nadja (1994),
#  movieId = 185, title = Net, The (1995),
#  movieId = 186, title = Nine Months (1995),
#  movieId = 187, title = Party Girl (1995),
#  movieId = 188, title = Prophecy, The (1995),
#  movieId = 189, title = Reckless (1995),
#  movieId = 190, title = Safe (1995),
#  movieId = 191, title = Scarlet Letter, The (1995),
#  movieId = 193, title = Showgirls (1995),
#  movieId = 194, title = Smoke (1995),
#  movieId = 195, title = Something to Talk About (1995),
#  movieId = 196, title = Species (1995),
#  movieId = 198, title = Strange Days (1995),
#  movieId = 199, title = Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964),
#  movieId = 201, title = Three Wishes (1995),
#  movieId = 202, title = Total Eclipse (1995),
#  movieId = 203, title = To Wong Foo, Thanks for Everything! Julie Newmar (1995),
#  movieId = 204, title = Under Siege 2: Dark Territory (1995),
#  movieId = 205, title = Unstrung Heroes (1995),
#  movieId = 206, title = Unzipped (1995),
#  movieId = 207, title = Walk in the Clouds, A (1995),
#  movieId = 208, title = Waterworld (1995),
#  movieId = 209, title = White Man's Burden (1995),
#  movieId = 210, title = Wild Bill (1995),
#  movieId = 211, title = Browning Version, The (1994),
#  movieId = 212, title = Bushwhacked (1995),
#  movieId = 213, title = Burnt by the Sun (Utomlyonnye solntsem) (1994),
#  movieId = 214, title = Before the Rain (Pred dozhdot) (1994),
#  movieId = 215, title = Before Sunrise (1995),
#  movieId = 216, title = Billy Madison (1995),
#  movieId = 217, title = Babysitter, The (1995),
#  movieId = 218, title = Boys on the Side (1995),
#  movieId = 219, title = Cure, The (1995),
#  movieId = 220, title = Castle Freak (1995),
#  movieId = 222, title = Circle of Friends (1995),
#  movieId = 223, title = Clerks (1994),
#  movieId = 224, title = Don Juan DeMarco (1995),
#  movieId = 225, title = Disclosure (1994),
#  movieId = 227, title = Drop Zone (1994),
#  movieId = 228, title = Destiny Turns on the Radio (1995),
#  movieId = 229, title = Death and the Maiden (1994),
#  movieId = 230, title = Dolores Claiborne (1995),
#  movieId = 231, title = Dumb & Dumber (Dumb and Dumber) (1994),
#  movieId = 232, title = Eat Drink Man Woman (Yin shi nan nu) (1994),
#  movieId = 233, title = Exotica (1994),
#  movieId = 234, title = Exit to Eden (1994),
#  movieId = 235, title = Ed Wood (1994),
#  movieId = 236, title = French Kiss (1995),
#  movieId = 237, title = Forget Paris (1995),
#  movieId = 238, title = Far From Home: The Adventures of Yellow Dog (1995),
#  movieId = 239, title = Goofy Movie, A (1995),
#  movieId = 240, title = Hideaway (1995),
#  movieId = 241, title = Fluke (1995),
#  movieId = 242, title = Farinelli: il castrato (1994),
#  movieId = 243, title = Gordy (1995),
#  movieId = 246, title = Hoop Dreams (1994),
#  movieId = 247, title = Heavenly Creatures (1994),
#  movieId = 248, title = Houseguest (1994),
#  movieId = 249, title = Immortal Beloved (1994),
#  movieId = 250, title = Heavyweights (Heavy Weights) (1995),
#  movieId = 251, title = Hunted, The (1995),
#  movieId = 252, title = I.Q. (1994),
#  movieId = 253, title = Interview with the Vampire: The Vampire Chronicles (1994),
#  movieId = 254, title = Jefferson in Paris (1995),
#  movieId = 255, title = Jerky Boys, The (1995),
#  movieId = 256, title = Junior (1994),
#  movieId = 257, title = Just Cause (1995),
#  movieId = 258, title = Kid in King Arthur's Court, A (1995),
#  movieId = 259, title = Kiss of Death (1995),
#  movieId = 260, title = Star Wars: Episode IV - A New Hope (1977),
#  movieId = 261, title = Little Women (1994),
#  movieId = 262, title = Little Princess, A (1995),
#  movieId = 263, title = Ladybird Ladybird (1994),
#  movieId = 265, title = Like Water for Chocolate (Como agua para chocolate) (1992),
#  movieId = 266, title = Legends of the Fall (1994),
#  movieId = 267, title = Major Payne (1995),
#  movieId = 269, title = My Crazy Life (Mi vida loca) (1993),
#  movieId = 270, title = Love Affair (1994),
#  movieId = 271, title = Losing Isaiah (1995),
#  movieId = 272, title = Madness of King George, The (1994),
#  movieId = 273, title = Mary Shelley's Frankenstein (Frankenstein) (1994),
#  movieId = 274, title = Man of the House (1995),
#  movieId = 275, title = Mixed Nuts (1994),
#  movieId = 276, title = Milk Money (1994),
#  movieId = 277, title = Miracle on 34th Street (1994),
#  movieId = 278, title = Miami Rhapsody (1995),
#  movieId = 279, title = My Family (1995),
#  movieId = 280, title = Murder in the First (1995),
#  movieId = 281, title = Nobody's Fool (1994),
#  movieId = 282, title = Nell (1994),
#  movieId = 283, title = New Jersey Drive (1995),
#  movieId = 284, title = New York Cop (Nyû Yôku no koppu) (1993),
#  movieId = 285, title = Beyond Bedlam (1993),
#  movieId = 287, title = Nina Takes a Lover (1994),
#  movieId = 288, title = Natural Born Killers (1994),
#  movieId = 289, title = Only You (1994),
#  movieId = 290, title = Once Were Warriors (1994),
#  movieId = 291, title = Poison Ivy II (1996),
#  movieId = 292, title = Outbreak (1995),
#  movieId = 293, title = Léon: The Professional (a.k.a. The Professional) (Léon) (1994),
#  movieId = 294, title = Perez Family, The (1995),
#  movieId = 295, title = Pyromaniac's Love Story, A (1995),
#  movieId = 296, title = Pulp Fiction (1994),
#  movieId = 298, title = Pushing Hands (Tui shou) (1992),
#  movieId = 299, title = Priest (1994),
#  movieId = 300, title = Quiz Show (1994),
#  movieId = 301, title = Picture Bride (Bijo photo) (1994),
#  movieId = 302, title = Queen Margot (Reine Margot, La) (1994),
#  movieId = 303, title = Quick and the Dead, The (1995),
#  movieId = 304, title = Roommates (1995),
#  movieId = 305, title = Ready to Wear (Pret-A-Porter) (1994),
#  movieId = 306, title = Three Colors: Red (Trois couleurs: Rouge) (1994),
#  movieId = 307, title = Three Colors: Blue (Trois couleurs: Bleu) (1993),
#  movieId = 308, title = Three Colors: White (Trzy kolory: Bialy) (1994),
#  movieId = 310, title = Rent-a-Kid (1995),
#  movieId = 311, title = Relative Fear (1994),
#  movieId = 312, title = Stuart Saves His Family (1995),
#  movieId = 313, title = Swan Princess, The (1994),
#  movieId = 314, title = Secret of Roan Inish, The (1994),
#  movieId = 315, title = Specialist, The (1994),
#  movieId = 316, title = Stargate (1994),
#  movieId = 317, title = Santa Clause, The (1994),
#  movieId = 318, title = Shawshank Redemption, The (1994),
#  movieId = 319, title = Shallow Grave (1994),
#  movieId = 320, title = Suture (1993),
#  movieId = 321, title = Strawberry and Chocolate (Fresa y chocolate) (1993),
#  movieId = 322, title = Swimming with Sharks (1995),
#  movieId = 324, title = Sum of Us, The (1994),
#  movieId = 325, title = National Lampoon's Senior Trip (1995),
#  movieId = 326, title = To Live (Huozhe) (1994),
#  movieId = 327, title = Tank Girl (1995),
#  movieId = 328, title = Tales from the Crypt Presents: Demon Knight (1995),
#  movieId = 329, title = Star Trek: Generations (1994),
#  movieId = 330, title = Tales from the Hood (1995),
#  movieId = 331, title = Tom & Viv (1994),
#  movieId = 332, title = Village of the Damned (1995),
#  movieId = 333, title = Tommy Boy (1995),
#  movieId = 334, title = Vanya on 42nd Street (1994),
#  movieId = 335, title = Underneath (1995),
#  movieId = 336, title = Walking Dead, The (1995),
#  movieId = 337, title = What's Eating Gilbert Grape (1993),
#  movieId = 338, title = Virtuosity (1995),
#  movieId = 339, title = While You Were Sleeping (1995),
#  movieId = 340, title = War, The (1994),
#  movieId = 341, title = Double Happiness (1994),
#  movieId = 342, title = Muriel's Wedding (1994),
#  movieId = 343, title = Baby-Sitters Club, The (1995),
#  movieId = 344, title = Ace Ventura: Pet Detective (1994),
#  movieId = 345, title = Adventures of Priscilla, Queen of the Desert, The (1994),
#  movieId = 346, title = Backbeat (1993),
#  movieId = 347, title = Bitter Moon (1992),
#  movieId = 348, title = Bullets Over Broadway (1994),
#  movieId = 349, title = Clear and Present Danger (1994),
#  movieId = 350, title = Client, The (1994),
#  movieId = 351, title = Corrina, Corrina (1994),
#  movieId = 352, title = Crooklyn (1994),
#  movieId = 353, title = Crow, The (1994),
#  movieId = 354, title = Cobb (1994),
#  movieId = 355, title = Flintstones, The (1994),
#  movieId = 356, title = Forrest Gump (1994),
#  movieId = 357, title = Four Weddings and a Funeral (1994),
#  movieId = 358, title = Higher Learning (1995),
#  movieId = 359, title = I Like It Like That (1994),
#  movieId = 360, title = I Love Trouble (1994),
#  movieId = 361, title = It Could Happen to You (1994),
#  movieId = 362, title = Jungle Book, The (1994),
#  movieId = 363, title = Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993),
#  movieId = 364, title = Lion King, The (1994),
#  movieId = 365, title = Little Buddha (1993),
#  movieId = 366, title = Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994),
#  movieId = 367, title = Mask, The (1994),
#  movieId = 368, title = Maverick (1994),
#  movieId = 369, title = Mrs. Parker and the Vicious Circle (1994),
#  movieId = 370, title = Naked Gun 33 1/3: The Final Insult (1994),
#  movieId = 371, title = Paper, The (1994),
#  movieId = 372, title = Reality Bites (1994),
#  movieId = 373, title = Red Rock West (1992),
#  movieId = 374, title = Richie Rich (1994),
#  movieId = 376, title = River Wild, The (1994),
#  movieId = 377, title = Speed (1994),
#  movieId = 378, title = Speechless (1994),
#  movieId = 379, title = Timecop (1994),
#  movieId = 380, title = True Lies (1994),
#  movieId = 381, title = When a Man Loves a Woman (1994),
#  movieId = 382, title = Wolf (1994),
#  movieId = 383, title = Wyatt Earp (1994),
#  movieId = 384, title = Bad Company (1995),
#  movieId = 385, title = Man of No Importance, A (1994),
#  movieId = 386, title = S.F.W. (1994),
#  movieId = 387, title = Low Down Dirty Shame, A (1994),
#  movieId = 388, title = Boys Life (1995),
#  movieId = 389, title = Colonel Chabert, Le (1994),
#  movieId = 390, title = Faster Pussycat! Kill! Kill! (1965),
#  movieId = 391, title = Jason's Lyric (1994),
#  movieId = 393, title = Street Fighter (1994),
#  movieId = 405, title = Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994),
#  movieId = 406, title = Federal Hill (1994),
#  movieId = 407, title = In the Mouth of Madness (1995),
#  movieId = 408, title = 8 Seconds (1994),
#  movieId = 409, title = Above the Rim (1994),
#  movieId = 410, title = Addams Family Values (1993),
#  movieId = 412, title = Age of Innocence, The (1993),
#  movieId = 413, title = Airheads (1994),
#  movieId = 414, title = Air Up There, The (1994),
#  movieId = 415, title = Another Stakeout (1993),
#  movieId = 416, title = Bad Girls (1994),
#  movieId = 417, title = Barcelona (1994),
#  movieId = 418, title = Being Human (1993),
#  movieId = 419, title = Beverly Hillbillies, The (1993),
#  movieId = 420, title = Beverly Hills Cop III (1994),
#  movieId = 421, title = Black Beauty (1994),
#  movieId = 422, title = Blink (1994),
#  movieId = 423, title = Blown Away (1994),
#  movieId = 424, title = Blue Chips (1994),
#  movieId = 425, title = Blue Sky (1994),
#  movieId = 426, title = Body Snatchers (1993),
#  movieId = 427, title = Boxing Helena (1993),
#  movieId = 428, title = Bronx Tale, A (1993),
#  movieId = 429, title = Cabin Boy (1994),
#  movieId = 430, title = Calendar Girl (1993),
#  movieId = 431, title = Carlito's Way (1993),
#  movieId = 432, title = City Slickers II: The Legend of Curly's Gold (1994),
#  movieId = 433, title = Clean Slate (1994),
#  movieId = 434, title = Cliffhanger (1993),
#  movieId = 435, title = Coneheads (1993),
#  movieId = 436, title = Color of Night (1994),
#  movieId = 437, title = Cops and Robbersons (1994),
#  movieId = 438, title = Cowboy Way, The (1994),
#  movieId = 440, title = Dave (1993),
#  movieId = 441, title = Dazed and Confused (1993),
#  movieId = 442, title = Demolition Man (1993),
#  movieId = 444, title = Even Cowgirls Get the Blues (1993),
#  movieId = 445, title = Fatal Instinct (1993),
#  movieId = 446, title = Farewell My Concubine (Ba wang bie ji) (1993),
#  movieId = 448, title = Fearless (1993),
#  movieId = 449, title = Fear of a Black Hat (1994),
#  movieId = 450, title = With Honors (1994),
#  movieId = 451, title = Flesh and Bone (1993),
#  movieId = 452, title = Widows' Peak (1994),
#  movieId = 453, title = For Love or Money (1993),
#  movieId = 454, title = Firm, The (1993),
#  movieId = 455, title = Free Willy (1993),
#  movieId = 456, title = Fresh (1994),
#  movieId = 457, title = Fugitive, The (1993),
#  movieId = 458, title = Geronimo: An American Legend (1993),
#  movieId = 459, title = Getaway, The (1994),
#  movieId = 460, title = Getting Even with Dad (1994),
#  movieId = 461, title = Go Fish (1994),
#  movieId = 464, title = Hard Target (1993),
#  movieId = 466, title = Hot Shots! Part Deux (1993),
#  movieId = 467, title = Live Nude Girls (1995),
#  movieId = 468, title = Englishman Who Went Up a Hill But Came Down a Mountain, The (1995),
#  movieId = 469, title = House of the Spirits, The (1993),
#  movieId = 470, title = House Party 3 (1994),
#  movieId = 471, title = Hudsucker Proxy, The (1994),
#  movieId = 472, title = I'll Do Anything (1994),
#  movieId = 473, title = In the Army Now (1994),
#  movieId = 474, title = In the Line of Fire (1993),
#  movieId = 475, title = In the Name of the Father (1993),
#  movieId = 476, title = Inkwell, The (1994),
#  movieId = 477, title = What's Love Got to Do with It? (1993),
#  movieId = 478, title = Jimmy Hollywood (1994),
#  movieId = 479, title = Judgment Night (1993),
#  movieId = 480, title = Jurassic Park (1993),
#  movieId = 481, title = Kalifornia (1993),
#  movieId = 482, title = Killing Zoe (1994),
#  movieId = 484, title = Lassie (1994),
#  movieId = 485, title = Last Action Hero (1993),
#  movieId = 486, title = Life with Mikey (1993),
#  movieId = 487, title = Lightning Jack (1994),
#  movieId = 488, title = M. Butterfly (1993),
#  movieId = 489, title = Made in America (1993),
#  movieId = 490, title = Malice (1993),
#  movieId = 491, title = Man Without a Face, The (1993),
#  movieId = 492, title = Manhattan Murder Mystery (1993),
#  movieId = 493, title = Menace II Society (1993),
#  movieId = 494, title = Executive Decision (1996),
#  movieId = 495, title = In the Realm of the Senses (Ai no corrida) (1976),
#  movieId = 496, title = What Happened Was... (1994),
#  movieId = 497, title = Much Ado About Nothing (1993),
#  movieId = 499, title = Mr. Wonderful (1993),
#  movieId = 500, title = Mrs. Doubtfire (1993),
#  movieId = 501, title = Naked (1993),
#  movieId = 502, title = Next Karate Kid, The (1994),
#  movieId = 504, title = No Escape (1994),
#  movieId = 505, title = North (1994),
#  movieId = 506, title = Orlando (1992),
#  movieId = 507, title = Perfect World, A (1993),
#  movieId = 508, title = Philadelphia (1993),
#  movieId = 509, title = Piano, The (1993),
#  movieId = 510, title = Poetic Justice (1993),
#  movieId = 511, title = Program, The (1993),
#  movieId = 512, title = Puppet Masters, The (1994),
#  movieId = 513, title = Radioland Murders (1994),
#  movieId = 514, title = Ref, The (1994),
#  movieId = 515, title = Remains of the Day, The (1993),
#  movieId = 516, title = Renaissance Man (1994),
#  movieId = 517, title = Rising Sun (1993),
#  movieId = 518, title = Road to Wellville, The (1994),
#  movieId = 519, title = RoboCop 3 (1993),
#  movieId = 520, title = Robin Hood: Men in Tights (1993),
#  movieId = 521, title = Romeo Is Bleeding (1993),
#  movieId = 522, title = Romper Stomper (1992),
#  movieId = 523, title = Ruby in Paradise (1993),
#  movieId = 524, title = Rudy (1993),
#  movieId = 526, title = Savage Nights (Nuits fauves, Les) (1992),
#  movieId = 527, title = Schindler's List (1993),
#  movieId = 528, title = Scout, The (1994),
#  movieId = 529, title = Searching for Bobby Fischer (1993),
#  movieId = 531, title = Secret Garden, The (1993),
#  movieId = 532, title = Serial Mom (1994),
#  movieId = 533, title = Shadow, The (1994),
#  movieId = 534, title = Shadowlands (1993),
#  movieId = 535, title = Short Cuts (1993),
#  movieId = 536, title = Simple Twist of Fate, A (1994),
#  movieId = 537, title = Sirens (1994),
#  movieId = 538, title = Six Degrees of Separation (1993),
#  movieId = 539, title = Sleepless in Seattle (1993),
#  movieId = 540, title = Sliver (1993),
#  movieId = 541, title = Blade Runner (1982),
#  movieId = 542, title = Son in Law (1993),
#  movieId = 543, title = So I Married an Axe Murderer (1993),
#  movieId = 544, title = Striking Distance (1993),
#  movieId = 546, title = Super Mario Bros. (1993),
#  movieId = 547, title = Surviving the Game (1994),
#  movieId = 548, title = Terminal Velocity (1994),
#  movieId = 549, title = Thirty-Two Short Films About Glenn Gould (1993),
#  movieId = 550, title = Threesome (1994),
#  movieId = 551, title = Nightmare Before Christmas, The (1993),
#  movieId = 552, title = Three Musketeers, The (1993),
#  movieId = 553, title = Tombstone (1993),
#  movieId = 555, title = True Romance (1993),
#  movieId = 556, title = War Room, The (1993),
#  movieId = 558, title = Pagemaster, The (1994),
#  movieId = 562, title = Welcome to the Dollhouse (1995),
#  movieId = 563, title = Germinal (1993),
#  movieId = 564, title = Chasers (1994),
#  movieId = 567, title = Kika (1993),
#  movieId = 568, title = Bhaji on the Beach (1993),
#  movieId = 569, title = Little Big League (1994),
#  movieId = 573, title = Ciao, Professore! (Io speriamo che me la cavo) (1992),
#  movieId = 574, title = Spanking the Monkey (1994),
#  movieId = 575, title = Little Rascals, The (1994),
#  movieId = 577, title = Andre (1994),
#  movieId = 579, title = Escort, The (Scorta, La) (1993),
#  movieId = 580, title = Princess Caraboo (1994),
#  movieId = 581, title = Celluloid Closet, The (1995),
#  movieId = 583, title = Dear Diary (Caro Diario) (1994),
#  movieId = 585, title = Brady Bunch Movie, The (1995),
#  movieId = 586, title = Home Alone (1990),
#  movieId = 587, title = Ghost (1990),
#  movieId = 588, title = Aladdin (1992),
#  movieId = 589, title = Terminator 2: Judgment Day (1991),
#  movieId = 590, title = Dances with Wolves (1990),
#  movieId = 592, title = Batman (1989),
#  movieId = 593, title = Silence of the Lambs, The (1991),
#  movieId = 594, title = Snow White and the Seven Dwarfs (1937),
#  movieId = 595, title = Beauty and the Beast (1991),
#  movieId = 596, title = Pinocchio (1940),
#  movieId = 597, title = Pretty Woman (1990),
#  movieId = 599, title = Wild Bunch, The (1969),
#  movieId = 600, title = Love and a .45 (1994),
#  movieId = 602, title = Great Day in Harlem, A (1994),
#  movieId = 605, title = One Fine Day (1996),
#  movieId = 606, title = Candyman: Farewell to the Flesh (1995),
#  movieId = 608, title = Fargo (1996),
#  movieId = 609, title = Homeward Bound II: Lost in San Francisco (1996),
#  movieId = 610, title = Heavy Metal (1981),
#  movieId = 611, title = Hellraiser: Bloodline (1996),
#  movieId = 612, title = Pallbearer, The (1996),
#  movieId = 613, title = Jane Eyre (1996),
#  movieId = 615, title = Bread and Chocolate (Pane e cioccolata) (1973),
#  movieId = 616, title = Aristocats, The (1970),
#  movieId = 617, title = Flower of My Secret, The (La flor de mi secreto) (1995),
#  movieId = 618, title = Two Much (1995),
#  movieId = 619, title = Ed (1996),
#  movieId = 626, title = Thin Line Between Love and Hate, A (1996),
#  movieId = 627, title = Last Supper, The (1995),
#  movieId = 628, title = Primal Fear (1996),
#  movieId = 631, title = All Dogs Go to Heaven 2 (1996),
#  movieId = 632, title = Land and Freedom (Tierra y libertad) (1995),
#  movieId = 633, title = Denise Calls Up (1995),
#  movieId = 634, title = Theodore Rex (1995),
#  movieId = 635, title = Family Thing, A (1996),
#  movieId = 636, title = Frisk (1995),
#  movieId = 637, title = Sgt. Bilko (1996),
#  movieId = 638, title = Jack and Sarah (1995),
#  movieId = 639, title = Girl 6 (1996),
#  movieId = 640, title = Diabolique (1996),
#  movieId = 645, title = Nelly & Monsieur Arnaud (1995),
#  movieId = 647, title = Courage Under Fire (1996),
#  movieId = 648, title = Mission: Impossible (1996),
#  movieId = 649, title = Cold Fever (Á köldum klaka) (1995),
#  movieId = 650, title = Moll Flanders (1996),
#  movieId = 653, title = Dragonheart (1996),
#  movieId = 656, title = Eddie (1996),
#  movieId = 661, title = James and the Giant Peach (1996),
#  movieId = 662, title = Fear (1996),
#  movieId = 663, title = Kids in the Hall: Brain Candy (1996),
#  movieId = 665, title = Underground (1995),
#  movieId = 667, title = Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996),
#  movieId = 668, title = Song of the Little Road (Pather Panchali) (1955),
#  movieId = 670, title = World of Apu, The (Apur Sansar) (1959),
#  movieId = 671, title = Mystery Science Theater 3000: The Movie (1996),
#  movieId = 673, title = Space Jam (1996),
#  movieId = 674, title = Barbarella (1968),
#  movieId = 678, title = Some Folks Call It a Sling Blade (1993),
#  movieId = 679, title = Run of the Country, The (1995),
#  movieId = 680, title = Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965),
#  movieId = 685, title = It's My Party (1996),
#  movieId = 688, title = Operation Dumbo Drop (1995),
#  movieId = 691, title = Mrs. Winterbourne (1996),
#  movieId = 692, title = Solo (1996),
#  movieId = 694, title = Substitute, The (1996),
#  movieId = 695, title = True Crime (1996),
#  movieId = 697, title = Feeling Minnesota (1996),
#  movieId = 698, title = Delta of Venus (1995),
#  movieId = 700, title = Angus (1995),
#  movieId = 703, title = Boys (1996),
#  movieId = 704, title = Quest, The (1996),
#  movieId = 706, title = Sunset Park (1996),
#  movieId = 707, title = Mulholland Falls (1996),
#  movieId = 708, title = Truth About Cats & Dogs, The (1996),
#  movieId = 709, title = Oliver & Company (1988),
#  movieId = 710, title = Celtic Pride (1996),
#  movieId = 711, title = Flipper (1996),
#  movieId = 714, title = Dead Man (1995),
#  movieId = 715, title = Horseman on the Roof, The (Hussard sur le toit, Le) (1995),
#  movieId = 718, title = Visitors, The (Visiteurs, Les) (1993),
#  movieId = 719, title = Multiplicity (1996),
#  movieId = 720, title = Wallace & Gromit: The Best of Aardman Animation (1996),
#  movieId = 722, title = Haunted World of Edward D. Wood Jr., The (1996),
#  movieId = 724, title = Craft, The (1996),
#  movieId = 725, title = Great White Hype, The (1996),
#  movieId = 726, title = Last Dance (1996),
#  movieId = 728, title = Cold Comfort Farm (1995),
#  movieId = 731, title = Heaven's Prisoners (1996),
#  movieId = 733, title = Rock, The (1996),
#  movieId = 735, title = Cemetery Man (Dellamorte Dellamore) (1994),
#  movieId = 736, title = Twister (1996),
#  movieId = 737, title = Barb Wire (1996),
#  movieId = 741, title = Ghost in the Shell (Kôkaku kidôtai) (1995),
#  movieId = 742, title = Thinner (1996),
#  movieId = 743, title = Spy Hard (1996),
#  movieId = 745, title = Wallace & Gromit: A Close Shave (1995),
#  movieId = 747, title = Stupids, The (1996),
#  movieId = 748, title = Arrival, The (1996),
#  movieId = 750, title = Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964),
#  movieId = 757, title = Ashes of Time (Dung che sai duk) (1994),
#  movieId = 759, title = Maya Lin: A Strong Clear Vision (1994),
#  movieId = 760, title = Stalingrad (1993),
#  movieId = 761, title = Phantom, The (1996),
#  movieId = 762, title = Striptease (1996),
#  movieId = 764, title = Heavy (1995),
#  movieId = 765, title = Jack (1996),
#  movieId = 766, title = I Shot Andy Warhol (1996),
#  movieId = 773, title = Touki Bouki (1973),
#  movieId = 775, title = Spirits of the Dead (1968),
#  movieId = 778, title = Trainspotting (1996),
#  movieId = 779, title = 'Til There Was You (1997),
#  movieId = 780, title = Independence Day (a.k.a. ID4) (1996),
#  movieId = 781, title = Stealing Beauty (1996),
#  movieId = 782, title = Fan, The (1996),
#  movieId = 783, title = Hunchback of Notre Dame, The (1996),
#  movieId = 784, title = Cable Guy, The (1996),
#  movieId = 785, title = Kingpin (1996),
#  movieId = 786, title = Eraser (1996),
#  movieId = 788, title = Nutty Professor, The (1996),
#  movieId = 790, title = Unforgettable Summer, An (Un été inoubliable) (1994),
#  movieId = 791, title = Last Klezmer: Leopold Kozlowski, His Life and Music, The (1994),
#  movieId = 795, title = Somebody to Love (1994),
#  movieId = 798, title = Daylight (1996),
#  movieId = 799, title = Frighteners, The (1996),
#  movieId = 800, title = Lone Star (1996),
#  movieId = 801, title = Harriet the Spy (1996),
#  movieId = 802, title = Phenomenon (1996),
#  movieId = 803, title = Walking and Talking (1996),
#  movieId = 804, title = She's the One (1996),
#  movieId = 805, title = Time to Kill, A (1996),
#  movieId = 806, title = American Buffalo (1996),
#  movieId = 808, title = Alaska (1996),
#  movieId = 809, title = Fled (1996),
#  movieId = 810, title = Kazaam (1996),
#  movieId = 813, title = Larger Than Life (1996),
#  movieId = 818, title = Very Brady Sequel, A (1996),
#  movieId = 823, title = Collector, The (La collectionneuse) (1967),
#  movieId = 824, title = Kaspar Hauser (1993),
#  movieId = 828, title = Adventures of Pinocchio, The (1996),
#  movieId = 829, title = Joe's Apartment (1996),
#  movieId = 830, title = First Wives Club, The (1996),
#  movieId = 832, title = Ransom (1996),
#  movieId = 833, title = High School High (1996),
#  movieId = 835, title = Foxfire (1996),
#  movieId = 836, title = Chain Reaction (1996),
#  movieId = 837, title = Matilda (1996),
#  movieId = 838, title = Emma (1996),
#  movieId = 839, title = Crow: City of Angels, The (1996),
#  movieId = 840, title = House Arrest (1996),
#  movieId = 841, title = Eyes Without a Face (Yeux sans visage, Les) (1959),
#  movieId = 842, title = Tales from the Crypt Presents: Bordello of Blood (1996),
#  movieId = 848, title = Spitfire Grill, The (1996),
#  movieId = 849, title = Escape from L.A. (1996),
#  movieId = 851, title = Basquiat (1996),
#  movieId = 852, title = Tin Cup (1996),
#  movieId = 858, title = Godfather, The (1972),
#  movieId = 861, title = Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992),
#  movieId = 866, title = Bound (1996),
#  movieId = 867, title = Carpool (1996),
#  movieId = 869, title = Kansas City (1996),
#  movieId = 870, title = Gone Fishin' (1997),
#  movieId = 875, title = Nothing to Lose (1994),
#  movieId = 876, title = Supercop 2 (Project S) (Chao ji ji hua) (1993),
#  movieId = 879, title = Relic, The (1997),
#  movieId = 880, title = Island of Dr. Moreau, The (1996),
#  movieId = 881, title = First Kid (1996),
#  movieId = 882, title = Trigger Effect, The (1996),
#  movieId = 885, title = Bogus (1996),
#  movieId = 886, title = Bulletproof (1996),
#  movieId = 888, title = Land Before Time III: The Time of the Great Giving (1995),
#  movieId = 889, title = 1-900 (06) (1994),
#  movieId = 891, title = Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995),
#  movieId = 892, title = Twelfth Night (1996),
#  movieId = 893, title = Mother Night (1996),
#  movieId = 896, title = Wild Reeds (Les roseaux sauvages) (1994),
#  movieId = 897, title = For Whom the Bell Tolls (1943),
#  movieId = 898, title = Philadelphia Story, The (1940),
#  movieId = 899, title = Singin' in the Rain (1952),
#  movieId = 900, title = American in Paris, An (1951),
#  movieId = 901, title = Funny Face (1957),
#  movieId = 902, title = Breakfast at Tiffany's (1961),
#  movieId = 903, title = Vertigo (1958),
#  movieId = 904, title = Rear Window (1954),
#  movieId = 905, title = It Happened One Night (1934),
#  movieId = 906, title = Gaslight (1944),
#  movieId = 907, title = Gay Divorcee, The (1934),
#  movieId = 908, title = North by Northwest (1959),
#  movieId = 909, title = Apartment, The (1960),
#  movieId = 910, title = Some Like It Hot (1959),
#  movieId = 911, title = Charade (1963),
#  movieId = 912, title = Casablanca (1942),
#  movieId = 913, title = Maltese Falcon, The (1941),
#  movieId = 914, title = My Fair Lady (1964),
#  movieId = 915, title = Sabrina (1954),
#  movieId = 916, title = Roman Holiday (1953),
#  movieId = 917, title = Little Princess, The (1939),
#  movieId = 918, title = Meet Me in St. Louis (1944),
#  movieId = 919, title = Wizard of Oz, The (1939),
#  movieId = 920, title = Gone with the Wind (1939),
#  movieId = 921, title = My Favorite Year (1982),
#  movieId = 922, title = Sunset Blvd. (a.k.a. Sunset Boulevard) (1950),
#  movieId = 923, title = Citizen Kane (1941),
#  movieId = 924, title = 2001: A Space Odyssey (1968),
#  movieId = 926, title = All About Eve (1950),
#  movieId = 927, title = Women, The (1939),
#  movieId = 928, title = Rebecca (1940),
#  movieId = 929, title = Foreign Correspondent (1940),
#  movieId = 930, title = Notorious (1946),
#  movieId = 931, title = Spellbound (1945),
#  movieId = 932, title = Affair to Remember, An (1957),
#  movieId = 933, title = To Catch a Thief (1955),
#  movieId = 934, title = Father of the Bride (1950),
#  movieId = 935, title = Band Wagon, The (1953),
#  movieId = 936, title = Ninotchka (1939),
#  movieId = 937, title = Love in the Afternoon (1957),
#  movieId = 938, title = Gigi (1958),
#  movieId = 940, title = Adventures of Robin Hood, The (1938),
#  movieId = 941, title = Mark of Zorro, The (1940),
#  movieId = 942, title = Laura (1944),
#  movieId = 943, title = Ghost and Mrs. Muir, The (1947),
#  movieId = 944, title = Lost Horizon (1937),
#  movieId = 945, title = Top Hat (1935),
#  movieId = 946, title = To Be or Not to Be (1942),
#  movieId = 947, title = My Man Godfrey (1936),
#  movieId = 948, title = Giant (1956),
#  movieId = 949, title = East of Eden (1955),
#  movieId = 950, title = Thin Man, The (1934),
#  movieId = 951, title = His Girl Friday (1940),
#  movieId = 952, title = Around the World in 80 Days (1956),
#  movieId = 953, title = It's a Wonderful Life (1946),
#  movieId = 954, title = Mr. Smith Goes to Washington (1939),
#  movieId = 955, title = Bringing Up Baby (1938),
#  movieId = 956, title = Penny Serenade (1941),
#  movieId = 959, title = Of Human Bondage (1934),
#  movieId = 961, title = Little Lord Fauntleroy (1936),
#  movieId = 963, title = Inspector General, The (1949),
#  movieId = 965, title = 39 Steps, The (1935),
#  movieId = 968, title = Night of the Living Dead (1968),
#  movieId = 969, title = African Queen, The (1951),
#  movieId = 970, title = Beat the Devil (1953),
#  movieId = 971, title = Cat on a Hot Tin Roof (1958),
#  movieId = 973, title = Meet John Doe (1941),
#  movieId = 976, title = Farewell to Arms, A (1932),
#  movieId = 979, title = Nothing Personal (1995),
#  movieId = 981, title = Dangerous Ground (1997),
#  movieId = 982, title = Picnic (1955),
#  movieId = 984, title = Pompatus of Love, The (1996),
#  movieId = 986, title = Fly Away Home (1996),
#  movieId = 987, title = Bliss (1997),
#  movieId = 988, title = Grace of My Heart (1996),
#  movieId = 990, title = Maximum Risk (1996),
#  movieId = 991, title = Michael Collins (1996),
#  movieId = 993, title = Infinity (1996),
#  movieId = 994, title = Big Night (1996),
#  movieId = 996, title = Last Man Standing (1996),
#  movieId = 998, title = Set It Off (1996),
#  movieId = 999, title = 2 Days in the Valley (1996),
#  movieId = 1003, title = Extreme Measures (1996),
#  movieId = 1004, title = Glimmer Man, The (1996),
#  movieId = 1005, title = D3: The Mighty Ducks (1996),
#  movieId = 1006, title = Chamber, The (1996),
#  movieId = 1007, title = Apple Dumpling Gang, The (1975),
#  movieId = 1008, title = Davy Crockett, King of the Wild Frontier (1955),
#  movieId = 1009, title = Escape to Witch Mountain (1975),
#  movieId = 1010, title = Love Bug, The (1969),
#  movieId = 1011, title = Herbie Rides Again (1974),
#  movieId = 1012, title = Old Yeller (1957),
#  movieId = 1013, title = Parent Trap, The (1961),
#  movieId = 1014, title = Pollyanna (1960),
#  movieId = 1015, title = Homeward Bound: The Incredible Journey (1993),
#  movieId = 1016, title = Shaggy Dog, The (1959),
#  movieId = 1017, title = Swiss Family Robinson (1960),
#  movieId = 1018, title = That Darn Cat! (1965),
#  movieId = 1019, title = 20,000 Leagues Under the Sea (1954),
#  movieId = 1020, title = Cool Runnings (1993),
#  movieId = 1021, title = Angels in the Outfield (1994),
#  movieId = 1022, title = Cinderella (1950),
#  movieId = 1023, title = Winnie the Pooh and the Blustery Day (1968),
#  movieId = 1024, title = Three Caballeros, The (1945),
#  movieId = 1025, title = Sword in the Stone, The (1963),
#  movieId = 1027, title = Robin Hood: Prince of Thieves (1991),
#  movieId = 1028, title = Mary Poppins (1964),
#  movieId = 1029, title = Dumbo (1941),
#  movieId = 1030, title = Pete's Dragon (1977),
#  movieId = 1031, title = Bedknobs and Broomsticks (1971),
#  movieId = 1032, title = Alice in Wonderland (1951),
#  movieId = 1033, title = Fox and the Hound, The (1981),
#  movieId = 1034, title = Freeway (1996),
#  movieId = 1035, title = Sound of Music, The (1965),
#  movieId = 1036, title = Die Hard (1988),
#  movieId = 1037, title = Lawnmower Man, The (1992),
#  movieId = 1040, title = Secret Agent, The (1996),
#  movieId = 1041, title = Secrets & Lies (1996),
#  movieId = 1042, title = That Thing You Do! (1996),
#  movieId = 1043, title = To Gillian on Her 37th Birthday (1996),
#  movieId = 1046, title = Beautiful Thing (1996),
#  movieId = 1047, title = Long Kiss Goodnight, The (1996),
#  movieId = 1049, title = Ghost and the Darkness, The (1996),
#  movieId = 1050, title = Looking for Richard (1996),
#  movieId = 1051, title = Trees Lounge (1996),
#  movieId = 1053, title = Normal Life (1996),
#  movieId = 1054, title = Get on the Bus (1996),
#  movieId = 1055, title = Shadow Conspiracy (1997),
#  movieId = 1056, title = Jude (1996),
#  movieId = 1057, title = Everyone Says I Love You (1996),
#  movieId = 1059, title = William Shakespeare's Romeo + Juliet (1996),
#  movieId = 1060, title = Swingers (1996),
#  movieId = 1061, title = Sleepers (1996),
#  movieId = 1064, title = Aladdin and the King of Thieves (1996),
#  movieId = 1066, title = Shall We Dance (1937),
#  movieId = 1068, title = Crossfire (1947),
#  movieId = 1073, title = Willy Wonka & the Chocolate Factory (1971),
#  movieId = 1076, title = Innocents, The (1961),
#  movieId = 1077, title = Sleeper (1973),
#  movieId = 1078, title = Bananas (1971),
#  movieId = 1079, title = Fish Called Wanda, A (1988),
#  movieId = 1080, title = Monty Python's Life of Brian (1979),
#  movieId = 1081, title = Victor/Victoria (1982),
#  movieId = 1082, title = Candidate, The (1972),
#  movieId = 1083, title = Great Race, The (1965),
#  movieId = 1084, title = Bonnie and Clyde (1967),
#  movieId = 1085, title = Old Man and the Sea, The (1958),
#  movieId = 1086, title = Dial M for Murder (1954),
#  movieId = 1088, title = Dirty Dancing (1987),
#  movieId = 1089, title = Reservoir Dogs (1992),
#  movieId = 1090, title = Platoon (1986),
#  movieId = 1091, title = Weekend at Bernie's (1989),
#  movieId = 1092, title = Basic Instinct (1992),
#  movieId = 1093, title = Doors, The (1991),
#  movieId = 1094, title = Crying Game, The (1992),
#  movieId = 1095, title = Glengarry Glen Ross (1992),
#  movieId = 1096, title = Sophie's Choice (1982),
#  movieId = 1097, title = E.T. the Extra-Terrestrial (1982),
#  movieId = 1099, title = Christmas Carol, A (1938),
#  movieId = 1100, title = Days of Thunder (1990),
#  movieId = 1101, title = Top Gun (1986),
#  movieId = 1103, title = Rebel Without a Cause (1955),
#  movieId = 1104, title = Streetcar Named Desire, A (1951),
#  movieId = 1105, title = Children of the Corn IV: The Gathering (1996),
#  movieId = 1107, title = Loser (1991),
#  movieId = 1111, title = Microcosmos (Microcosmos: Le peuple de l'herbe) (1996),
#  movieId = 1112, title = Palookaville (1996),
#  movieId = 1114, title = Funeral, The (1996),
#  movieId = 1116, title = Single Girl, A (Fille seule, La) (1995),
#  movieId = 1117, title = Eighth Day, The (Huitième jour, Le) (1996),
#  movieId = 1119, title = Drunks (1995),
#  movieId = 1120, title = People vs. Larry Flynt, The (1996),
#  movieId = 1121, title = Glory Daze (1995),
#  movieId = 1123, title = Perfect Candidate, A (1996),
#  movieId = 1124, title = On Golden Pond (1981),
#  movieId = 1125, title = Return of the Pink Panther, The (1975),
#  movieId = 1126, title = Drop Dead Fred (1991),
#  movieId = 1127, title = Abyss, The (1989),
#  movieId = 1128, title = Fog, The (1980),
#  movieId = 1129, title = Escape from New York (1981),
#  movieId = 1130, title = Howling, The (1980),
#  movieId = 1131, title = Jean de Florette (1986),
#  movieId = 1132, title = Manon of the Spring (Manon des sources) (1986),
#  movieId = 1135, title = Private Benjamin (1980),
#  movieId = 1136, title = Monty Python and the Holy Grail (1975),
#  movieId = 1137, title = Hustler White (1996),
#  movieId = 1140, title = Entertaining Angels: The Dorothy Day Story (1996),
#  movieId = 1144, title = Line King: The Al Hirschfeld Story, The (1996),
#  movieId = 1147, title = When We Were Kings (1996),
#  movieId = 1148, title = Wallace & Gromit: The Wrong Trousers (1993),
#  movieId = 1150, title = Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982),
#  movieId = 1151, title = Lesson Faust (1994),
#  movieId = 1156, title = Children Are Watching Us, The (Bambini ci guardano, I) (1944),
#  movieId = 1161, title = Tin Drum, The (Blechtrommel, Die) (1979),
#  movieId = 1162, title = Ruling Class, The (1972),
#  movieId = 1163, title = Mina Tannenbaum (1994),
#  movieId = 1167, title = Dear God (1996),
#  movieId = 1170, title = Best of the Best 3: No Turning Back (1995),
#  movieId = 1171, title = Bob Roberts (1992),
#  movieId = 1172, title = Cinema Paradiso (Nuovo cinema Paradiso) (1989),
#  movieId = 1173, title = Cook the Thief His Wife & Her Lover, The (1989),
#  movieId = 1175, title = Delicatessen (1991),
#  movieId = 1176, title = Double Life of Veronique, The (Double Vie de Véronique, La) (1991),
#  movieId = 1177, title = Enchanted April (1992),
#  movieId = 1178, title = Paths of Glory (1957),
#  movieId = 1179, title = Grifters, The (1990),
#  movieId = 1180, title = Hear My Song (1991),
#  movieId = 1183, title = English Patient, The (1996),
#  movieId = 1184, title = Mediterraneo (1991),
#  movieId = 1185, title = My Left Foot (1989),
#  movieId = 1186, title = Sex, Lies, and Videotape (1989),
#  movieId = 1187, title = Passion Fish (1992),
#  movieId = 1188, title = Strictly Ballroom (1992),
#  movieId = 1189, title = Thin Blue Line, The (1988),
#  movieId = 1190, title = Tie Me Up! Tie Me Down! (¡Átame!) (1990),
#  movieId = 1191, title = Madonna: Truth or Dare (1991),
#  movieId = 1192, title = Paris Is Burning (1990),
#  movieId = 1193, title = One Flew Over the Cuckoo's Nest (1975),
#  movieId = 1194, title = Cheech and Chong's Up in Smoke (1978),
#  movieId = 1196, title = Star Wars: Episode V - The Empire Strikes Back (1980),
#  movieId = 1197, title = Princess Bride, The (1987),
#  movieId = 1198, title = Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981),
#  movieId = 1199, title = Brazil (1985),
#  movieId = 1200, title = Aliens (1986),
#  movieId = 1201, title = Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966),
#  movieId = 1202, title = Withnail & I (1987),
#  movieId = 1203, title = 12 Angry Men (1957),
#  movieId = 1204, title = Lawrence of Arabia (1962),
#  movieId = 1206, title = Clockwork Orange, A (1971),
#  movieId = 1207, title = To Kill a Mockingbird (1962),
#  movieId = 1208, title = Apocalypse Now (1979),
#  movieId = 1209, title = Once Upon a Time in the West (C'era una volta il West) (1968),
#  movieId = 1210, title = Star Wars: Episode VI - Return of the Jedi (1983),
#  movieId = 1211, title = Wings of Desire (Himmel über Berlin, Der) (1987),
#  movieId = 1212, title = Third Man, The (1949),
#  movieId = 1213, title = Goodfellas (1990),
#  movieId = 1214, title = Alien (1979),
#  movieId = 1215, title = Army of Darkness (1993),
#  movieId = 1216, title = Big Blue, The (Grand bleu, Le) (1988),
#  movieId = 1217, title = Ran (1985),
#  movieId = 1218, title = Killer, The (Die xue shuang xiong) (1989),
#  movieId = 1219, title = Psycho (1960),
#  movieId = 1220, title = Blues Brothers, The (1980),
#  movieId = 1221, title = Godfather: Part II, The (1974),
#  movieId = 1222, title = Full Metal Jacket (1987),
#  movieId = 1223, title = Grand Day Out with Wallace and Gromit, A (1989),
#  movieId = 1224, title = Henry V (1989),
#  movieId = 1225, title = Amadeus (1984),
#  movieId = 1226, title = Quiet Man, The (1952),
#  movieId = 1227, title = Once Upon a Time in America (1984),
#  movieId = 1228, title = Raging Bull (1980),
#  movieId = 1230, title = Annie Hall (1977),
#  movieId = 1231, title = Right Stuff, The (1983),
#  movieId = 1232, title = Stalker (1979),
#  movieId = 1233, title = Boot, Das (Boat, The) (1981),
#  movieId = 1234, title = Sting, The (1973),
#  movieId = 1235, title = Harold and Maude (1971),
#  movieId = 1236, title = Trust (1990),
#  movieId = 1237, title = Seventh Seal, The (Sjunde inseglet, Det) (1957),
#  movieId = 1238, title = Local Hero (1983),
#  movieId = 1240, title = Terminator, The (1984),
#  movieId = 1241, title = Dead Alive (Braindead) (1992),
#  movieId = 1242, title = Glory (1989),
#  movieId = 1243, title = Rosencrantz and Guildenstern Are Dead (1990),
#  movieId = 1244, title = Manhattan (1979),
#  movieId = 1245, title = Miller's Crossing (1990),
#  movieId = 1246, title = Dead Poets Society (1989),
#  movieId = 1247, title = Graduate, The (1967),
#  movieId = 1248, title = Touch of Evil (1958),
#  movieId = 1249, title = Femme Nikita, La (Nikita) (1990),
#  movieId = 1250, title = Bridge on the River Kwai, The (1957),
#  movieId = 1251, title = 8 1/2 (8½) (1963),
#  movieId = 1252, title = Chinatown (1974),
#  movieId = 1253, title = Day the Earth Stood Still, The (1951),
#  movieId = 1254, title = Treasure of the Sierra Madre, The (1948),
#  movieId = 1255, title = Bad Taste (1987),
#  movieId = 1256, title = Duck Soup (1933),
#  movieId = 1257, title = Better Off Dead... (1985),
#  movieId = 1258, title = Shining, The (1980),
#  movieId = 1259, title = Stand by Me (1986),
#  movieId = 1260, title = M (1931),
#  movieId = 1261, title = Evil Dead II (Dead by Dawn) (1987),
#  movieId = 1262, title = Great Escape, The (1963),
#  movieId = 1263, title = Deer Hunter, The (1978),
#  movieId = 1264, title = Diva (1981),
#  movieId = 1265, title = Groundhog Day (1993),
#  movieId = 1266, title = Unforgiven (1992),
#  movieId = 1267, title = Manchurian Candidate, The (1962),
#  movieId = 1268, title = Pump Up the Volume (1990),
#  movieId = 1269, title = Arsenic and Old Lace (1944),
#  movieId = 1270, title = Back to the Future (1985),
#  movieId = 1271, title = Fried Green Tomatoes (1991),
#  movieId = 1272, title = Patton (1970),
#  movieId = 1273, title = Down by Law (1986),
#  movieId = 1274, title = Akira (1988),
#  movieId = 1275, title = Highlander (1986),
#  movieId = 1276, title = Cool Hand Luke (1967),
#  movieId = 1277, title = Cyrano de Bergerac (1990),
#  movieId = 1278, title = Young Frankenstein (1974),
#  movieId = 1279, title = Night on Earth (1991),
#  movieId = 1280, title = Raise the Red Lantern (Da hong deng long gao gao gua) (1991),
#  movieId = 1281, title = Great Dictator, The (1940),
#  movieId = 1282, title = Fantasia (1940),
#  movieId = 1283, title = High Noon (1952),
#  movieId = 1284, title = Big Sleep, The (1946),
#  movieId = 1285, title = Heathers (1989),
#  movieId = 1286, title = Somewhere in Time (1980),
#  movieId = 1287, title = Ben-Hur (1959),
#  movieId = 1288, title = This Is Spinal Tap (1984),
#  movieId = 1289, title = Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983),
#  movieId = 1290, title = Some Kind of Wonderful (1987),
#  movieId = 1291, title = Indiana Jones and the Last Crusade (1989),
#  movieId = 1292, title = Being There (1979),
#  movieId = 1293, title = Gandhi (1982),
#  movieId = 1295, title = Unbearable Lightness of Being, The (1988),
#  movieId = 1296, title = Room with a View, A (1986),
#  movieId = 1297, title = Real Genius (1985),
#  movieId = 1298, title = Pink Floyd: The Wall (1982),
#  movieId = 1299, title = Killing Fields, The (1984),
#  movieId = 1300, title = My Life as a Dog (Mitt liv som hund) (1985),
#  movieId = 1301, title = Forbidden Planet (1956),
#  ...]
